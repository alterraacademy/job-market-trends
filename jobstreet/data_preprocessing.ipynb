# %%
import pandas as pd

# %%
job_dataset = pd.read_csv('jobstreet_cleaned_3.csv')

# %%
job_dataset.isnull().sum()
# Out:
# Job Title                 0
# Company Name              1
# Location                  0
# Salary                    0
# Job Classification        0
# Job Sub Classification    0
# Facility                  0
# Posted Date               0
# Job Type                  0
# Job Description           0
# More Detail               0
# og_period_salary          0
# Compensation              0
# og_salary_currency        0
# Job ID                    0
# Job Category              0
# Scraped Date              0
# dtype: int64

# %%
job_dataset[job_dataset['Job Title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Job Title, Company Name, Location, Salary, Job Classification, Job Sub Classification, Facility, Posted Date, Job Type, Job Description, More Detail, og_period_salary, Compensation, og_salary_currency, Job ID, Job Category, Scraped Date]
# Index: []

# %%
# job_categories = {
#     'administration': ['admin', 'administrasi', 'administrative', 'administrative assistant', 'executive assistant', 'office assistant','personal assistant'],
#     'beauty': ['beautician', 'beauty', 'beauty therapist', 'klinik kecantikan', 'lash artist', 'nail artist'],
#     'blockchain': ['blockchain', 'blockchain architect', 'blockchain consultant', 'blockchain developer', 'cryptocurrency analyst', 'smart contract developer'],
#     'business intelligence': ['business intelligence','bisnis analis', 'business analyst', 'it business'],
#     'cloud computing': ['cloud', 'cloud consultant', 'cloud devops engineer', 'cloud engineer', 'cloud infrastructure engineer', 'cloud security specialist', 'cloud solutions architect'],
#     'construction': ['architect', 'construction', 'kontraktor','sipil','civil','structural'],
#     'consulting': ['business consultant', 'consultant'],
#     'customer service': ['call center agent', 'customer', 'customer service', 'customer success', 'support'],
#     'cyber security': ['cyber', 'cyber security', 'data privacy', 'network security', 'security'],
#     'data': ['data', 'data analyst', 'data engineer', 'data scientist', 'database administrator'],
#     'design': ['design', 'desain', 'designer', 'editor', 'grafis', 'graphic', 'interior','ui', 'user experience', 'ux', 'ux researcher', 'ux writer', 'user interface'],
#     'education': ['academic', 'curriculum developer', 'dosen', 'education', 'guru', 'lecturer', 'professor', 'school counselor', 'teacher', 'tutor'],
#     'engineering': ['aerospace', 'chemical', 'electrical', 'engineer', 'mechanic', 'mechanical', 'teknikal', 'teknisi'],
#     'event organizer': ['event', 'organizer', 'planner', 'wedding'],
#     'finance': ['audit', 'auditor', 'financial', 'investment banker''accountant', 'accounting', 'akunting', 'finance'],
#     'healthcare': ['dokter', 'doctor', 'health', 'laboratorium', 'medical', 'medical technician', 'nurse', 'paramedic', 'pharmacist', 'radiologist', 'surgeon', 'terapis'],
#     'hospitality': ['bakery', 'barista', 'bartender', 'cafe', 'cook', 'dapur', 'food', 'food and beverage', 'front desk agent', 'hotel', 'kitchen', 'koki', 'receptionist', 'restaurant', 'resto', 'restoran', 'villa', 'waiter', 'waitress','front office'],
#     'human resources': ['hr', 'hrd', 'human resource', 'payroll', 'recruitment', 'talent acquisition', 'training'],
#     'information system': ['erp', 'information system', 'system analyst', 'odoo', 'sap','system'],
#     'it': ['ai', 'ai engineer', 'ai ethics specialist', 'ai ml', 'ai project', 'ai research scientist', 'ai trainer', 'backend', 'back end', 'cloud', 'dev ops', 'devops', 'devops engineer', 'flutter', 'front end', 'front-end', 'full stack', 'fullstack', 'golang', 'help desk technician', 'ios developer', 'it', 'it manager', 'it risk management', 'it service desk', 'it staff', 'java', 'javascript developer', 'machine learning', 'machine learning engineer', 'ml analyst', 'ml consultant', 'ml engineer', 'ml modeler', 'ml researcher', 'mobile apps', 'mobile developer', 'mobile programmer', 'nextjs', 'php developer', 'python', 'react', 'security specialist', 'software developer', 'software engineer', 'systems analysis', 'technical support', 'web', 'web desain', 'web designer', 'web developer'],
#     'legal': ['lawyer', 'legal', 'legal assistant', 'paralegal'],
#     'logistics & transportation': ['driver', 'ekspedisi', 'export', 'import', 'logistic'],
#     'manufacturing': ['manufacturing engineer', 'production', 'produksi'],
#     'sales & marketing': ['sales', 'marketing', 'seo'],
#     'media and communications': ['communications', 'journalist', 'public relations'],
#     'network administration': ['network', 'network administrator'],
#     'nonprofit': ['fundraising', 'program', 'volunteer'],
#     'operations': ['operasional', 'operations', 'warehouse', 'gudang','area','operational'],
#     'product management': ['it presales(ordo)', 'product', 'product analyst', 'product owner', 'project'],
#     'quality control': ['quality', 'quality assurance', 'quality control', 'software quality assurance', 'qa', 'qc'],
#     'real estate': ['property', 'real estate'],
#     'researcher': ['research', 'research analyst', 'research scientist', 'rnd', 'riset'],
#     'retail': ['sales associate', 'store', 'visual merchandiser'],
#     'social media': ['content creator', 'content writer', 'copywriter', 'content writer','influencer', 'konten kreator', 'live', 'live streaming', 'social media', 'streamer', 'talent'],
#     'supply chain': ['supply chain'],
#     'tax': ['pajak', 'tax', 'tax consultant'],
#     'translator': ['bahasa', 'interpreter', 'penerjemah', 'speaker', 'translator'],
# }

# # Create a new column 'Job Category' with default value 'Other'
# job_dataset['Job Category'] = 'Other'

# # Convert job titles and categories to lowercase for case-insensitive comparison
# job_dataset['Job Title'] = job_dataset['Job Title'].str.lower()
# job_categories = {key.upper(): [title.lower() for title in titles] for key, titles in job_categories.items()}

# # Iterate over job categories and update 'Job Category' column based on job title
# for category, keywords in job_categories.items():
#     try:
#         for keyword in keywords:
#             job_dataset.loc[job_dataset['Job Title'].str.contains(keyword, na=False, regex=False), 'Job Category'] = category
#     except ValueError as e:
#         print(f"ValueError: {e}")
#         print(f"Problematic rows: {job_dataset[job_dataset['Job Title'].str.contains(keyword)].index}")

# %%
job_categories = {
    # 'administration': ['admin', 'administrasi', 'administrative', 'administrative assistant', 'executive assistant', 'office assistant','personal assistant'],
    # 'beauty': ['beautician', 'beauty', 'beauty therapist', 'klinik kecantikan', 'lash artist', 'nail artist'],
    'blockchain': ['blockchain', 'blockchain architect', 'blockchain consultant', 'blockchain developer', 'cryptocurrency analyst', 'smart contract developer'],
    'business intelligence': ['business intelligence','bisnis analis', 'business analyst', 'it business'],
    'cloud computing': ['cloud', 'cloud consultant', 'cloud devops engineer', 'cloud engineer', 'cloud infrastructure engineer', 'cloud security specialist', 'cloud solutions architect'],
    # 'construction': ['architect', 'construction', 'kontraktor','sipil','civil','structural'],
    # 'consulting': ['business consultant', 'consultant'],
    # 'customer service': ['call center agent', 'customer', 'customer service', 'customer success', 'support'],
    'cyber security': ['cyber', 'cyber security', 'data privacy', 'network security', 'security'],
    'data': ['data', 'data analyst', 'data engineer', 'data scientist', 'database administrator'],
    # 'design': ['design', 'desain', 'designer', 'editor', 'grafis', 'graphic', 'interior','ui', 'user experience', 'ux', 'ux researcher', 'ux writer', 'user interface'],
    # 'education': ['academic', 'curriculum developer', 'dosen', 'education', 'guru', 'lecturer', 'professor', 'school counselor', 'teacher', 'tutor'],
    # 'engineering': ['aerospace', 'chemical', 'electrical', 'engineer', 'mechanic', 'mechanical', 'teknikal', 'teknisi'],
    # 'event organizer': ['event', 'organizer', 'planner', 'wedding'],
    # 'finance': ['audit', 'auditor', 'financial', 'investment banker''accountant', 'accounting', 'akunting', 'finance'],
    # 'healthcare': ['dokter', 'doctor', 'health', 'laboratorium', 'medical', 'medical technician', 'nurse', 'paramedic', 'pharmacist', 'radiologist', 'surgeon', 'terapis'],
    # 'hospitality': ['bakery', 'barista', 'bartender', 'cafe', 'cook', 'dapur', 'food', 'food and beverage', 'front desk agent', 'hotel', 'kitchen', 'koki', 'receptionist', 'restaurant', 'resto', 'restoran', 'villa', 'waiter', 'waitress','front office'],
    # 'human resources': ['hr', 'hrd', 'human resource', 'payroll', 'recruitment', 'talent acquisition', 'training'],
    'information system': ['erp', 'information system', 'system analyst', 'odoo', 'sap','system'],
    'ai engineer': ['ai', 'ai engineer', 'ai ethics specialist', 'ai ml', 'ai project', 'ai research scientist', 'ai trainer', 'machine learning', 'machine learning engineer', 'ml analyst', 'ml consultant', 'ml engineer', 'ml modeler', 'ml researcher'],
    'backend engineer':['backend', 'back end', 'golang', 'java', 'php', 'python','back-end','.net','c#'],
    'frontend engineer':['flutter', 'front end', 'front-end', 'javascript developer', 'react', 'web', 'web desain', 'web designer', 'web developer','frontend'],
    'fullstack engineer':['full stack', 'fullstack', 'nextjs'],
    'mobile developer':['ios developer', 'mobile apps', 'mobile developer', 'mobile programmer'],
    'devops engineer':['dev ops', 'devops', 'devops engineer'],
    'software engineer':['software developer', 'software engineer'],
    'system analyst':['systems analysis','system'],
    'it support':['help desk technician', 'it', 'it manager', 'it risk management', 'it service desk', 'it staff', 'technical support'],

    # 'it': ['ai', 'ai engineer', 'ai ethics specialist', 'ai ml', 'ai project', 'ai research scientist', 'ai trainer', 'backend', 'back end', 'cloud', 'dev ops', 'devops', 'devops engineer', 'flutter', 'front end', 'front-end', 'full stack', 'fullstack', 'golang', 'help desk technician', 'ios developer', 'it', 'it manager', 'it risk management', 'it service desk', 'it staff', 'java', 'javascript developer', 'machine learning', 'machine learning engineer', 'ml analyst', 'ml consultant', 'ml engineer', 'ml modeler', 'ml researcher', 'mobile apps', 'mobile developer', 'mobile programmer', 'nextjs', 'php developer', 'python', 'react', 'security specialist', 'software developer', 'software engineer', 'systems analysis', 'technical support', 'web', 'web desain', 'web designer', 'web developer'],
    # 'legal': ['lawyer', 'legal', 'legal assistant', 'paralegal'],
    # 'logistics & transportation': ['driver', 'ekspedisi', 'export', 'import', 'logistic'],
    # 'manufacturing': ['manufacturing engineer', 'production', 'produksi'],
    # 'sales & marketing': ['sales', 'marketing', 'seo'],
    # 'media and communications': ['communications', 'journalist', 'public relations'],
    'network administration': ['network', 'network administrator'],
    # 'nonprofit': ['fundraising', 'program', 'volunteer'],
    # 'operations': ['operasional', 'operations', 'warehouse', 'gudang','area','operational'],
    'product management': ['it presales(ordo)', 'product', 'product analyst', 'product owner', 'project'],
    'quality control': ['quality', 'quality assurance', 'quality control', 'software quality assurance', 'qa', 'qc'],
    # 'real estate': ['property', 'real estate'],
    # 'researcher': ['research', 'research analyst', 'research scientist', 'rnd', 'riset'],
    # 'retail': ['sales associate', 'store', 'visual merchandiser'],
    # 'social media': ['content creator', 'content writer', 'copywriter', 'content writer','influencer', 'konten kreator', 'live', 'live streaming', 'social media', 'streamer', 'talent'],
    # 'supply chain': ['supply chain'],
    # 'tax': ['pajak', 'tax', 'tax consultant'],
    # 'translator': ['bahasa', 'interpreter', 'penerjemah', 'speaker', 'translator'],
}

# Create a new column 'Job Category' with default value 'Other'
job_dataset['Job Sub Category IT'] = 'Other'

# Convert job titles and categories to lowercase for case-insensitive comparison
job_dataset['Job Title'] = job_dataset['Job Title'].str.lower()
job_categories_it = {key.upper(): [title.lower() for title in titles] for key, titles in job_categories_it.items()}

# Iterate over job categories and update 'Job Category' column based on job title
for category, keywords in job_categories_it.items():
    try:
        for keyword in keywords:
            job_dataset.loc[job_dataset['Job Title'].str.contains(keyword, na=False, regex=False), 'Job Sub Category IT'] = category
    except ValueError as e:
        print(f"ValueError: {e}")
        print(f"Problematic rows: {job_dataset[job_dataset['Job Title'].str.contains(keyword)].index}")

# %%
job_dataset['Job Sub Category IT'].value_counts()
# Out:
# Job Sub Category IT
# Other                     1712
# DEVOPS ENGINEER            177
# AI ENGINEER                 97
# QUALITY CONTROL             43
# DATA                        21
# INFORMATION SYSTEM          19
# DESIGN                      17
# IT SUPPORT                  13
# IT MANAGEMENT               10
# NETWORK ADMINISTRATION       8
# BACKEND ENGINEER             6
# BUSINESS INTELLIGENCE        3
# FULLSTACK ENGINEER           2
# Name: count, dtype: int64

# %%
job_dataset['Company Name'].value_counts()
# Out:
# Company Name
# Not Written                          73
# Pt Yakult Indonesia Persada          12
# Pt Nusantara Ekspres Kilat            9
# Pt Erela                              8
# Pt Amman Mineral Nusa Tenggara        8
#                                      ..
# Skinseoul Pte Ltd                     1
# Pt United Friends Indonesia Medan     1
# Archiola                              1
# Pt Enseval Putera Megatrading Tbk     1
# Pt Riung Mitra Lestari                1
# Name: count, Length: 1522, dtype: int64

# %%
# create new column 'Scraped Date' with default value '2024-03-03'
job_dataset['Scraped Date'] = '2024-03-13'

# %%
job_dataset.to_csv('jobstreet_cleaned_3.csv', index=False)

# %%
# job_dataset['Company Name'].value_counts().to_csv('company_name_counts.csv')

# %%
# job_dataset['Job Category'].value_counts().to_csv('job_category_counts.csv')

# %% [markdown]
# # Remove based on Not Related Classification & Sub Cassification

# %% [markdown]
# # Delete Unrelated Data to Tech

# %%
# delete unrelated data to tech industry
job_dataset = job_dataset[~((job_dataset['Job Category'] == 'Other') & (job_dataset['Job Title'].str.contains('akuntan', case=False)))]
job_dataset = job_dataset[~(job_dataset['Job Title'].str.contains('graphic designer', case=False))]
job_dataset = job_dataset[~(job_dataset['Job Title'].str.contains('graphic design', case=False))]

# %%
job_dataset[(job_dataset['Job Category'] == 'Other')]

# %%
job_dataset[((job_dataset['Job Category'] == 'Other') & (job_dataset['Job Classification'] == 'Pemasaran & Komunikasi'))].to_csv('call_center.csv', index=False)

# %%
# job_dataset[(job_dataset[job_dataset['Job Category'] == 'Other']) & (job_dataset[job_dataset['Job Classification'] == 'Ritel & Produk Konsumen'])]

job_dataset = job_dataset[~((job_dataset['Job Category'] == 'Other') & (job_dataset['Job Classification'].str.contains('Ritel & Produk Konsumen', case=False)))]

# %%
job_dataset[(job_dataset['Job Classification'] != 'Teknologi Informasi & Komunikasi') &
              (job_dataset['Job Classification'] != 'Sains & Teknologi') &
              (job_dataset['Job Classification'] != 'Teknik')&
              (job_dataset['Job Classification'] != 'Pendidikan & Pelatihan')&
              (job_dataset['Job Classification'] != 'Konsultasi & Strategi')&
              (job_dataset['Job Classification'] != 'Sumber Daya Manusia & Perekrutan')&
              (job_dataset['Job Sub Classification'] != 'Manajemen Akun & Relasi')&
                (job_dataset['Job Classification'] != 'Pemasaran & Komunikasi')&
                (job_dataset['Job Sub Classification'] != 'Matematika, Statistik & Teknik Informasi') &
              (job_dataset['Job Sub Classification'] != 'Developer/Programmer')&
               (job_dataset['Job Sub Classification'] != 'Pengembangan Bisnis Baru')&
              (job_dataset['Job Sub Classification'] != 'Teknik – Perangkat Lunak')&
              (job_dataset['Job Sub Classification'] != 'Manajemen & Administrasi Database')&
              (job_dataset['Job Sub Classification'] != 'Manajemen & Pengembangan Produk')&
            (job_dataset['Job Sub Classification'] != 'Pengajaran – Pendidikan Tinggi')&
            (job_dataset['Job Sub Classification'] != 'Desain Web & Interaksi	')&   
            (job_dataset['Job Sub Classification'] != 'Teknik – Perangkat Keras (Hardware Engineering)')&
            (job_dataset['Job Sub Classification'] != 'Teknik – Jaringan (Network Engineering)')&
            (job_dataset['Job Sub Classification'] != 'Teknik Sistem (Systems Engineering)')]
# Out:
#                                                Job Title  \
# 8                        operator mesin laser uv marking
# 274    assistant manager for fatty alcohol process en...
# 275                 procurement - international sourcing
# 276                                       branch manager
# 277                                       branch manager
# ...                                                  ...
# 20439                                     graphic design
# 20481                                           designer
# 20483                                     graphic design
# 20492                              senior graphic design
# 20493            creative operations specialist (remote)
#
#                              Company Name        Location  \
# 8                            Solusi segel   Jakarta Barat
# 274    PT Unilever Oleochemical Indonesia  Sumatera Utara
# 275        PT Amman Mineral Nusa Tenggara         Sumbawa
# ...

# %%
job_title = ['data engineer','web developer','ui/ux designer', 'ai','artificial intelligence engineer','ai engineer','ml engineer','machine learning','backend developer','back-end','big data engineer','blockchain engineer','business intelligence','cloud architect','cloud engineer','cyber security','data analyst','data scientist','database administrator','devops engineer','front-end','frontend developer','mobile','full stack developer','helpdesk technicial','it manager','it support','machine learning engineer','network administrator','network engineer','product manager','software quality assurance','security specialist','software engineer','systems analyst','ui designer','user experience designer','mobile developer','game developer','ios developer','java developer','javascript developer','linux administrator','network architect','network security','php developer','python developer','ruby developer','software developer','system administrator','web designer','ux designer','programmer','engineer','developer','cloud','IT','backend','tech','project manager','product manager','system','erp','odoo','product owner','informatika','product analyst']

# %%
job_data =[]
for job in job_title:
    combined = job_dataset[job_dataset['Job Title'].str.contains(job, case=False)]
    job_data.append(combined)
# others = job_dataset[~job_dataset['Job Title'].str.contains('|'.join(job_title), case=False)]
    
job_data = pd.concat(job_data, ignore_index=True)
job_data = job_data.drop_duplicates()
# job_data.to_csv('job_data_.csv', index=False)

# %%
# delete job title that is claim analyst
job_data = job_data[~job_data['Job Title'].str.contains('claim analyst', case=False)]
job_data = job_data[~job_data['Job Title'].str.contains('claim', case=False)]

# job_data.to_csv('job_data.csv', index=False)

# %%
# delete job title that is area retail
job_data = job_data[~job_data['Job Title'].str.contains('area retail', case=False)]

# %%
# delete job title that is planner
job_data = job_data[~job_data['Job Title'].str.contains('planner', case=False)]

# %%
# delete job title that is planner
# job_data[job_data['Job Title'].str.contains('operator', case=False)]
job_data = job_data[~job_data['Job Title'].str.contains('management trainee', case=False)]
# job_data[job_data['Job Title'].str.contains('trainee', case=False)]

# %%
job_data = job_data[~job_data['Job Title'].str.contains('retail operation', case=False)]

# %%
job_data[(job_data['Job Category'] == 'Other') & (job_data['Job Title'].str.contains('programmer', case=False))].head(50)

# %%
job_categories = {
    'data_engineering': ['data engineer'],
    'web_development': ['web developer', 'frontend', 'backend','back-end', 'full stack', 'web designer','fullstack','web developer ','web desain','front-end','front end ','back end','web programmer'],
    'ui_ux': ['ui/ux','uiux','ui/ux designer','ui designer','user experience designer','ux designer'],
    'ai_ml_engineering': ['ai engineer', 'ml engineer', 'machine learning', 'machine learning engineer','ai ',' ai/ml '],
    'business_intelligence': ['business intelligence'],
    'business_analyst': ['business analyst'],   
    'cloud_engineering': ['cloud engineer','cloud engineer '],
    'cyber_security': ['cyber security', 'network security','cyber security '],
    'data_analysis': ['data analyst',' data analyst'],
    'data_science': ['data scientist'],
    'database_administration': ['database administrator'],
    'devops': ['devops engineer', 'devops'],
    'it_management': ['it manager'],
    'it_support': ['it support'],
    'network_administration': ['network administrator'],
    'product_management': ['product manager', 'product owner', 'product analyst'],
    'software_quality_assurance': ['software quality assurance'],
    'security_specialist': ['security specialist'],
    'software_engineering': ['software engineer', 'software developer', 'java developer', 'python developer', 'php developer', 'ruby', 'javascript developer'],
    'systems_analysis': ['systems analyst', 'system administrator','system analyst'],
    'mobile_development': ['mobile developer', 'ios developer','mobile programmer','android developer','flutter','mobile apps'],
    'game_development': ['game'],
    'dosen/guru': ['dosen', 'guru'],
    'erp': ['erp', 'odoo'],
    'supply chain': ['supply chain']
}

# Create a new column 'Job Category' with default value 'Other'
job_data['Job Category'] = 'Other'

# Convert job titles and categories to lowercase for case-insensitive comparison
job_data['Job Title'] = job_data['Job Title'].str.lower()
job_categories = {key: [title.lower() for title in titles] for key, titles in job_categories.items()}

# Iterate over job categories and update 'Job Category' column based on job title
for category, keywords in job_categories.items():
    for keyword in keywords:
        job_data.loc[job_data['Job Title'].str.contains(keyword), 'Job Category'] = category

# Display the updated DataFrame
print(job_data)
# Out:
#                                      Job Title  \
# 0                                data engineer
# 1                                data engineer
# 2                                data engineer
# 3                      data engineer (bandung)
# 4                      data engineer (officer)
# ...                                        ...
# 15193                          product analyst
# 15194  senior product analyst - coupon product
# 15195                          product analyst
# 15196  senior product analyst - coupon product
# 15197                          product analyst
#
#                                  Company Name           Location  \
# 0      PT Nomura Research Institute Indonesia       Jakarta Raya
# 1                    PT Kamoro Maxima Integra    Jakarta Selatan
# 2           PT Nusantara Duta Solusindo (NDS)    Jakarta Selatan
# 3                    PT Jasamedika Saranatama         Jawa Barat
# 4                                  Dexa Group  Tangerang Selatan
# ...

# %%
# count job_categories value
job_data['Job Category'].value_counts()
# Out:
# Job Category
# Other                         3010
# web_development                571
# software_engineering           270
# it_support                     125
# product_management             120
# data_analysis                  114
# mobile_development             105
# systems_analysis                91
# data_engineering                89
# ui_ux                           87
# erp                             81
# devops                          71
# data_science                    48
# business_analyst                44
# software_quality_assurance      44
# ai_ml_engineering               41
# cyber_security                  36
# database_administration         31
# cloud_engineering               29
# supply chain                    27
# business_intelligence           24
# it_management                   22
# dosen/guru                       5
# security_specialist              5
# network_administration           3
# game_development                 1
# ...

# %%
job_data[job_data['Job Category'] == 'Other'].tail(50)
# Out:
#                                                Job Title  \
# 14633  staff system & organization development (cikande)
# 14634    business process manager (system and procedure)
# 14635  management information system officer (contrat...
# 14638         management & system development specialist
# 14641           system development & integration manager
# 14647  lecturer specialist - master in information sy...
# 14650                                  system integrator
# 14651  management information system (mis) specialist...
# 14653  management information system officer (contrat...
# 14655  management information system (mis) specialist...
# 14656  specialist – distributed control system (dcs) ...
# 14657  coo office analyst - learning management syste...
# 14663                       land management system staff
# 14664                  officer business process & system
# 14666    application support specialist, finance systems
# ...

# %%
job_title = ['data engineer','web developer','ui/ux','ai engineer','ml engineer','machine learning','backend','business intelligence','cloud engineer','cyber security','data analyst','data scientist','database administrator','devops engineer','frontend','full stack','it manager','it support','machine learning engineer','network administrator','network engineer','product manager','software quality assurance','security specialist','software engineer','systems analyst','mobile developer','game','ios developer','java developer','javascript developer','network security','php developer','python developer','ruby','software developer','system administrator','web designer','project manager','erp','odoo','product owner','informatika','product analyst']

total_each_job = []
for job in job_title:
    data =job_data[job_data['Job Title'].str.contains(job, case=False)]
    total_each_job.append({'Job Title': job, 'Total Count': len(data)})

# merge front-end and frontend


# total_each_job
# sort total_each_job by Total Count
total_each_job = sorted(total_each_job, key=lambda x: x['Total Count'], reverse=True)
total_each_job
# Out:
# [{'Job Title': 'backend', 'Total Count': 168},
#  {'Job Title': 'software engineer', 'Total Count': 166},
#  {'Job Title': 'it support', 'Total Count': 127},
#  {'Job Title': 'project manager', 'Total Count': 121},
#  {'Job Title': 'data analyst', 'Total Count': 117},
#  {'Job Title': 'full stack', 'Total Count': 93},
#  {'Job Title': 'data engineer', 'Total Count': 91},
#  {'Job Title': 'web developer', 'Total Count': 89},
#  {'Job Title': 'product manager', 'Total Count': 87},
#  {'Job Title': 'network engineer', 'Total Count': 76},
#  {'Job Title': 'frontend', 'Total Count': 69},
#  {'Job Title': 'ui/ux', 'Total Count': 63},
#  {'Job Title': 'erp', 'Total Count': 61},
#  {'Job Title': 'devops engineer', 'Total Count': 58},
#  {'Job Title': 'data scientist', 'Total Count': 48},
#  {'Job Title': 'software quality assurance', 'Total Count': 44},
#  {'Job Title': 'java developer', 'Total Count': 39},
#  {'Job Title': 'software developer', 'Total Count': 37},
# ...

# %%
# example for checking each job
it_support = job_data[job_data['Job Title'].str.contains('game', case=False)]
it_support
# Out:
#                                               Job Title  \
# 5367  Senior Site Reliability Engineer (Games) - Sea...
#
#                         Company Name      Location       Salary  \
# 5367  Shopee Internasional Indonesia  Jakarta Raya  Not Written
#
#                     Job Classification          Job Sub Classification  \
# 5367  Teknologi Informasi & Komunikasi  Administrasi Jaringan & Sistem
#
#      Job Description     Facility Posted Date  \
# 5367     Not Written  Not Written  2024-03-01
#
#                                             More Detail
# 5367  https://www.jobstreet.co.id/id/job/74155285?ty...

# %%
not_tech = ['Pertanian, Hewan & Konservasi', 'Pekerjaan Lepas', 'Olahraga & Rekreasi', 'Periklanan, Seni & Media', 'Layanan & Pengembangan Masyarakat', 'Pemerintahan & Pertahanan', 'Asuransi & Dana Pensiun','CEO & Manajemen Umum','Real Estat & Properti',  'Call Center & Layanan Konsumen', 'Akuntansi', 'Sumber Daya Manusia & Perekrutan',   'Pertambangan, Sumber Daya Alam & Energi','Konstruksi','Hospitaliti & Pariwisata','Ritel & Produk Konsumen','Perbankan & Layanan Finansial','Desain & Arsitektur','Pemasaran & Komunikasi',  'Administrasi & Dukungan Perkantoran','Kesehatan & Medis']
# job classification not tech
for classification in not_tech:
    job_dataset = job_dataset[~((job_dataset['Job Category'] == 'Other') & (job_dataset['Job Classification'] == classification))]
not_tech_sub = [['Arsitek',
 'Keamanan',
 'Pembelian, Pengadaan & Inventaris',
 'Teknik Sipil/Struktural',
 'Perwakilan/Konsultan Penjualan',
 'Kebijakan',
 'Asisten Pribadi, Asisten Eksekutif & Sekretarial',
 'Pergudangan, Penyimpanan & Distribusi',
 'Kimia & Fisika',
 'Pekerjaan Perakitan & Pemrosesan',
 'Hukum Korporasi & Komersil',
 'Pelatihan & Penilaian Tempat Kerja',
 'Pialang & Jual Beli Saham',
 'Penulisan Teknis',
 'Agen/Konsultan Perjalanan',
 'Asisten Administratif',
 'Strategi & Perencanaan',
 'Merchandiser',
 'Manajemen Akun & Hubungan',
 'Manajemen – Universitas',
 'Psikologi, Konseling & Kerja Sosial',
 'Kepatuhan & Resiko',
 'Audit – Internal',
 'Desain Interior',
 'Pengapalan/Pengurusan Transportasi',
 'Penjualan – Pra & Pasca',
 'Tata Rambut & Kecantikan',
 'Staf Hukum & Paralegal',
 'Teknik Lingkungan',
 'Layanan Konsumen – Call Center',
 'Rekayasa Proses',
 'Teknik – Perangkat Keras',
 'Manajemen Praktik Hukum',
 'Penelitian Klinis/Medis',
 'Koordinator Penjualan',
 'Jasa Laboratorium & Teknis',
 'Layanan Klien',
 'Penelitian & Beasiswa',
 'Ilmu Biologi & Biomedis',
 'Pengajaran – Pendidikan Dasar',
 'Perkebunan & Penataan Lanskap',
 'Drafting Teknik',
 'Teknik Fasilitas Bangunan',
 'Pemimpin Tim/Supervisor',
 'Teknik Mesin',
 'Supervisor',
 'Pemeliharaan',
 'Teknik Kimia',
 'Teknik Lapangan',
 'Penjahit & Pembuatan Baju',
 'Jasa Kebersihan',
 'Manajemen Kontrak',
 'Hukum Kekayaan Intelektual',
 'Teknik Penanganan Material',
 'Teknik Pengairan & Limbah',
 'Perangkat Farmasi & Medis',
 'Ilmu Material',
 'Jasa Otomotif',
 'Keperawatan – Medis & Pembedahan Umum',
 'Kredit',
 'Remunerasi & Tunjangan',
 'Jasa Perpustakaan & Manajemen Informasi',
 'Umum – In-house',
 'Pengajaran – Pendidikan Menengah',
 'Transportasi Jalan',
 'Pengelas & Pembuat Ketel Uap',
 'Impor/Ekspor & Pabean',
 'Litigasi & Resolusi Konflik',
 'Pengajaran – Pendidikan Usia Dini',
 'Penjualan',
 'Manajemen & Dukungan',
 'Jasa Percetakan & Penerbitan',
 'Manajemen – Sekolah',
 'Kurir, Sopir & Jasa Pos',
 'Pramusiwi & Pengasuh Bayi',
 'Bimbingan Siswa',
 'Lingkungan, Bumi & Geosains',
 'Jasa Keamanan',
 'Manajemen Pertanian',
 'Bioteknologi & Genetika',
 'Jurnalisme & Penulisan',
 'Manajemen – Kejuruan',
 'Keperawatan - Operasi & Pemulihan',
 'Asisten Ritel',
 'Farmasi',
 'Terapi Alami & Pengobatan Tradisional',
 'Hukum Perbankan & Finansial',
 'Audit – Eksternal',
 'Pendinginan Udara & Pembekuan',
 'COO & Direktur Utama',
 'Administrasi Medis',
 'Hukum Lingkungan & Perencanaan',
 'Asisten/Koordinator Pemasaran',
 'Manajemen Armada',
 'Jasa Penerbangan',
 'Pengambilan & Pengepakan',
 'Transportasi Rel & Maritim',
 'Buruh',
 'Desain Industri']]
# job sub classification not tech
for sub in not_tech_sub:
    job_dataset = job_dataset[~((job_dataset['Job Category'] == 'Other') & (job_dataset['Job Sub Classification'].isin([sub])))]

# %% [markdown]
# # Check Posted Date

# %%
job_dataset = pd.read_csv('jobstreet_cleaned_2.csv')

# %%
current_date = '2024-03-13'

job_dataset.loc[job_dataset['Posted Date'].str.contains('jam'), 'Posted Date'] = current_date
job_dataset.loc[job_dataset['Posted Date'].str.contains('menit'), 'Posted Date'] = current_date

# %%
job_dataset.loc[job_dataset['Posted Date'].str.contains('12024'), 'Posted Date'] = '2024-03-11'

# %%
job_dataset.to_csv('cleanedd.csv')
