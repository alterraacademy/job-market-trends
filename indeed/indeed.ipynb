# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
import urllib.parse
import re, json

# %%
from scrapfly import ScrapflyClient, ScrapeConfig
from urllib.parse import urlencode
# import asyncio 

scrapfly = ScrapflyClient(key="scp-live-10421fbda886456f885ee18e9e914588")

result = scrapfly.scrape(ScrapeConfig(
    url="https://www.indeed.com/jobs?q=python&l=Texas",
    asp=True,
))
print(result.selector.xpath('//h1').get())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 11
#       5 scrapfly = ScrapflyClient(key="scp-live-10421fbda886456f885ee18e9e914588")
#       7 result = scrapfly.scrape(ScrapeConfig(
#       8     url="https://www.indeed.com/jobs?q=python&l=Texas",
#       9     asp=True,
#      10 ))
# ---> 11 print(result.selector.xpath('//h1').get().text)
#
# AttributeError: 'str' object has no attribute 'text'

# %%
def parse_search_page(html: str):
    data = re.findall(r'window.mosaic.providerData\["mosaic-provider-jobcards"\]=(\{.+?\});', html)
    data = json.loads(data[0])
    return {
        "results": data["metaData"]["mosaicProviderJobCardsModel"]["results"],
        "meta": data["metaData"]["mosaicProviderJobCardsModel"]["tierSummaries"],
    }

async def scrape_search(query: str, location: str, max_results: int = 50):
    def make_page_url(offset):
        parameters = {"q": query, "l": location, "filter": 0, "start": offset}
        return "https://www.indeed.com/jobs?" + urlencode(parameters)

    print(f"scraping first page of search: {query=}, {location=}")
    result_first_page = await scrapfly.async_scrape(ScrapeConfig(make_page_url(0), asp=True))
    data_first_page = parse_search_page(result_first_page.content)

    results = data_first_page["results"]
    total_results = sum(category["jobCount"] for category in data_first_page["meta"])
    # there's a page limit on indeed.com of 1000 results per search
    if total_results > max_results:
        total_results = max_results
    print(f"scraping remaining {total_results - 10 / 10} pages")
    other_pages = [
        ScrapeConfig(make_page_url(offset), asp=True) 
        for offset in range(10, total_results + 10, 10)
    ]
    async for result in scrapfly.concurrent_scrape(other_pages):
        results.extend(parse_search_page(result.content))
    return results

# %%
import re
import json
from typing import List
from scrapfly import ScrapeConfig, ScrapflyClient

scrapfly = ScrapflyClient(key="scp-live-10421fbda886456f885ee18e9e914588")


def parse_job_page(html):
    """parse job data from job listing page"""
    data = re.findall(r"_initialData=(\{.+?\});", html)
    data = json.loads(data[0])
    return data["jobInfoWrapperModel"]["jobInfoModel"]


async def scrape_jobs(job_keys: List[str]):
    """scrape job details from job page for given job keys"""
    urls = [f"https://www.indeed.com/m/basecamp/viewjob?viewtype=embedded&jk={job_key}" for job_key in job_keys]
    to_scrape = [ScrapeConfig(url=url, asp=True) for url in urls]
    scraped = []
    async for result in scrapfly.concurrent_scrape(to_scrape):
        scraped.append(parse_job_page(result.content))
    return scraped

# %%
parse_job_page('https://www.indeed.com/jobs?q=python&l=Texas')

# %%
import re
import json
import httpx
import asyncio
from typing import List


def parse_job_page(html):
    """parse job data from job listing page"""
    data = re.findall(r"_initialData=(\{.+?\});", html)
    data = json.loads(data[0])
    return data["jobInfoWrapperModel"]["jobInfoModel"]


async def scrape_jobs(client: httpx.AsyncClient, job_keys: List[str]):
    """scrape job details from job page for given job keys"""
    urls = [f"https://www.indeed.com/m/basecamp/viewjob?viewtype=embedded&jk={job_key}" for job_key in job_keys]
    scraped = []
    for response in await asyncio.gather(*[client.get(url=url) for url in urls]):
        scraped.append(parse_job_page(response.text))
    return scraped

# %%
async def main():
    HEADERS = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
        "Connection": "keep-alive",
        "Accept-Language": "en-US,en;q=0.9,lt;q=0.8,et;q=0.7,de;q=0.6",
    }
    async with httpx.AsyncClient(headers=HEADERS) as client:
        job_data = await scrape_jobs(client, ["a82cf0bd2092efa3"])
        print(job_data[0]['sanitizedJobDescription']['content'])
        print(job_data)

asyncio.run(main())
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\genericpath.py:77: RuntimeWarning: coroutine 'main' was never awaited
#   m = tuple(map(os.fspath, m))
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[37], line 14
#      11         print(job_data[0]['sanitizedJobDescription']['content'])
#      12         print(job_data)
# ---> 14 asyncio.run(main())
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\asyncio\runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#      37     raise ValueError("a coroutine was expected, got {!r}".format(main))
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
from scrapfly import ScrapflyClient, ScrapeConfig

scrapfly = ScrapflyClient(key="scp-live-10421fbda886456f885ee18e9e914588")

searched_position = 'python'
location = 'indonesia'

result = scrapfly.scrape(ScrapeConfig(
    url = "https://www.indeed.com/jobs?q={}&l={}".format(searched_position,location),
    asp=True,
))
print(result.selector.xpath('//h1').get())
# result
# Out:
# <h1 class="css-novqjp e1tiznh50">python jobs</h1>

# %%
def convert_columns_data_type(df, cols, datatype):
    for col in cols:
        df[col] = df[col].astype(datatype)
        
def scrape_job_details(page_source):
    content = BeautifulSoup(page_source, 'lxml')
    # print(content)
    jobs_list = []    
    for post in content.select('.job_seen_beacon'):

        data = {
            "job_title": post.find('span', id=lambda x: x and x.startswith('jobTitle')).text,
            "company": post.find('span', class_='css-92r8pb').text,
            "location": post.find('div', class_='css-1p0sjhy').text,
            "posted_date":  post.find('span', attrs={'data-testid': 'myJobsStateDate'}).text,
            "job_description": post.find('div', class_='css-9446fg').text,
            "job_type": post.find('span', class_='css-12bzcbs').text,
            "scrapped_date": pd.to_datetime('today').strftime('%Y-%m-%d')
        }

        try: data["rating"] = post.find('span', attrs={'data-testid': 'holistic-rating'}).text
        except: data["rating"] = 0
        jobs_list.append(data)

    df = pd.DataFrame(jobs_list)
    if 'rating' in df.columns:
        convert_columns_data_type(df, ['rating'], np.float32) # Convert rating to float

    return df

new_results = []
job_search = input('Enter searched position: ')
job_query = urllib.parse.quote(job_search)
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

for i in range(10):
    url = 'https://id.indeed.com/jobs?q={}&start={}&l=&from=searchOnHP'.format(job_query,10 + i*10)
    response = requests.get(url, headers=headers)
    result = scrape_job_details(response.content)
    new_results.append(result)
combined_data = pd.concat(new_results, ignore_index=True)

combined_data.to_csv('indeed.csv')
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="in">
# <head>
# <link href="/images/favicon.ico" rel="shortcut icon"/>
# <title>Lowongan Frontend Developer bulan 13 Mei 2024 | Indeed.com</title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="Ada perusahaan yang sedang membuka kesempatan lowongan kerja Frontend Developer, Front End Developer, Web Developer, Developer dan banyak lagi melalui Indeed.com." name="description"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="noindex" name="robots"/>
# <link href="jobs?q=frontend+developer&amp;l=&amp;from=searchOnHP&amp;jlid=dd616958bd9ddc12&amp;forceLocation=-1&amp;rbsalmin=0&amp;rbsalmax=0&amp;start=0" rel="prev"/>
# <link href="/jobs?q=frontend+developer&amp;l=&amp;from=searchOnHP&amp;jlid=dd616958bd9ddc12&amp;forceLocation=-1&amp;rbsalmin=0&amp;rbsalmax=0&amp;start=20" rel="next"/>
# <link href="https://id.indeed.com/q-frontend-developer-lowongan.html" rel="canonical"/>
# <link href="android-app://com.indeed.android.jobsearch/https/id.indeed.com/m/jobs?q=frontend+developer&amp;start=10&amp;l=&amp;from=searchOnHP" rel="alternate"/>
# <link href="ios-app://https/id.indeed.com/m/jobs?q=frontend+developer&amp;start=10&amp;l=&amp;from=searchOnHP" rel="alternate"/>
# <link href="http://id.indeed.com/rss?q=frontend+developer" rel="alternate" title="Lowongan, Pekerjaan frontend developer" type="application/rss+xml"/>
# <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <style>
#         html body *, html body div .gnav * { font-family: 'Noto Sans', 'Helvetica Neue', Helvetica, Arial, sans-serif !important; }
#     </style>
# <link href="//c03.s3.indeed.com/m/s/78d51e8ebdcc4ea28570/styles/serpWithOpenvjGlobal.css" rel="stylesheet"/>
# <script id="mobile-shared-dep-modules">
#         window._INDEED = window._INDEED || {};
#         window._INDEED.modules = [{"container":"mobileSharedDeps","module":".\u002FSerpWithOpenDynamicVjGlobal","shareScope":"react17","urls":["\u002F\u002Fc03.s3.indeed.com\u002Fm\u002Fs\u002Fscripts\u002Freact17\u002FmobileSharedDeps.remoteEntry.0daa80a37e7dacae4829.js"]}];
#         window.addEventListener("DOMContentLoaded",()=>{window._INDEED&&window._INDEED.modules&&window._INDEED.modules.forEach(d=>{var e=()=>{window._INDEED.shared.v1.load("module",d)};window._INDEED&&window._INDEED.shared&&window._INDEED.shared.v1?e():window.addEventListener("onSharedDepsLoadersV1Available",e,{once:!0})})});</script>
# <link as="script" crossorigin="anonymous" href="//c03.s3.indeed.com/m/s/scripts/react17/mobileSharedDeps.remoteEntry.0daa80a37e7dacae4829.js" rel="preload"/>
# </head><body><div id="preLoadingIndicator" style="height: 100vh">
# <div style="display: flex; flex-direction: column; align-items: center; position: absolute; top: 50%; left: 50%; transform: translateY(-50%); margin-top: -32px; margin-left: -75px">
# <svg fill="none" height="31" style="margin-bottom:2rem" width="113" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M111.92 5.689c-.398-.446-.93-.672-1.65-.672-.719 0-1.269.238-1.652.73-.382.475-.581 1.19-.581 2.126v6.785c-.885-.953-1.804-1.637-2.737-2.098a6.838 6.838 0 0 0-2.034-.595c-.443-.06-.902-.091-1.405-.091-2.339 0-4.234.804-5.687 2.412-1.437 1.608-2.156 3.84-2.156 6.708 0 1.356.184 2.62.549 3.78.37 1.159.885 2.172 1.59 3.033a7.462 7.462 0 0 0 2.507 1.995c.962.46 2.002.698 3.132.698a7.71 7.71 0 0 0 1.466-.132 5.83 5.83 0 0 0 .887-.211 7.637 7.637 0 0 0 2.003-1.01c.626-.447 1.254-1.028 1.88-1.726v.446c0 .848.214 1.488.626 1.95.43.446.964.683 1.605.683.657 0 1.192-.223 1.604-.653.411-.446.627-1.101.627-1.977V7.638c.007-.85-.192-1.505-.574-1.949Zm-4.754 18.715c-.412.862-.964 1.503-1.635 1.92a4.276 4.276 0 0 1-2.265.624h-.014a4.183 4.183 0 0 1-2.264-.653c-.689-.446-1.238-1.101-1.634-1.963-.395-.878-.594-1.934-.594-3.185 0-1.176.182-2.215.566-3.093.367-.893.901-1.577 1.575-2.052.689-.492 1.454-.715 2.322-.715h.046c.81 0 1.559.237 2.247.698.689.46 1.238 1.133 1.65 2.009.413.878.612 1.934.612 3.153 0 1.308-.199 2.396-.612 3.257Zm-14.844.195c-.29-.252-.688-.387-1.178-.387-.443 0-.78.106-1.024.298-.597.535-1.07.967-1.439 1.279-.365.298-.78.595-1.22.876a4.903 4.903 0 0 1-1.344.598 5.697 5.697 0 0 1-1.545.192c-.122 0-.244 0-.352-.015a4.244 4.244 0 0 1-1.955-.595c-.705-.4-1.255-.994-1.684-1.769-.412-.804-.626-1.725-.64-2.767h9.217c1.238 0 2.2-.18 2.874-.506.688-.358 1.024-1.102 1.024-2.247 0-1.25-.336-2.47-.993-3.674-.657-1.193-1.636-2.175-2.965-2.93-1.316-.759-2.89-1.131-4.74-1.131h-.136c-1.36.014-2.614.24-3.73.655a8.31 8.31 0 0 0-2.952 1.903 8.516 8.516 0 0 0-1.801 2.99 11.236 11.236 0 0 0-.629 3.778c0 2.888.842 5.148 2.523 6.828 1.588 1.594 3.79 2.427 6.587 2.516.153.014.319.014.489.014 1.314 0 2.49-.163 3.514-.504 1.024-.343 1.866-.76 2.54-1.265.669-.52 1.175-1.056 1.511-1.605.336-.55.506-1.042.506-1.445 0-.463-.151-.835-.458-1.087ZM81.317 16.19c.751-.79 1.713-1.176 2.89-1.176h.018c1.22 0 2.216.387 2.964 1.16.75.775 1.192 1.95 1.3 3.525h-8.546c.151-1.545.612-2.721 1.374-3.509Zm-9.066 8.019c-.458 0-.794.105-1.038.297-.58.536-1.07.968-1.437 1.28-.367.297-.765.595-1.209.876a4.971 4.971 0 0 1-1.36.597 5.612 5.612 0 0 1-1.544.192c-.12 0-.243 0-.35-.014a4.262 4.262 0 0 1-1.958-.595c-.686-.401-1.252-.994-1.664-1.77-.43-.803-.643-1.725-.66-2.766h9.232c1.223 0 2.185-.18 2.873-.507.672-.357 1.01-1.101 1.01-2.246 0-1.25-.321-2.47-.979-3.675-.657-1.192-1.65-2.174-2.964-2.93-1.317-.758-2.905-1.13-4.737-1.13h-.154c-1.36.014-2.597.24-3.73.655-1.163.446-2.141 1.087-2.935 1.903a8.31 8.31 0 0 0-1.818 2.99c-.415 1.162-.629 2.427-.629 3.778 0 2.887.856 5.148 2.538 6.828 1.59 1.594 3.775 2.426 6.572 2.515.168.015.319.015.49.015 1.328 0 2.491-.164 3.513-.504 1.024-.344 1.866-.761 2.538-1.265.688-.521 1.177-1.056 1.513-1.606.336-.55.506-1.041.506-1.445 0-.46-.153-.832-.444-1.084-.302-.255-.702-.39-1.175-.39Zm-9.843-8.019c.748-.79 1.712-1.176 2.89-1.176h.017c1.22 0 2.216.387 2.964 1.16.763.775 1.192 1.95 1.315 3.525h-8.56c.167-1.545.628-2.721 1.374-3.509ZM9.82 27.455V16.503c.32.03.626.044.948.044 1.527 0 2.966-.401 4.187-1.116v12.021c0 1.027-.244 1.786-.72 2.292-.472.504-1.1.756-1.863.756-.75 0-1.345-.252-1.835-.773-.472-.504-.717-1.262-.717-2.272ZM54.221 5.689c-.398-.446-.947-.672-1.635-.672-.72 0-1.27.238-1.653.73-.396.475-.58 1.19-.58 2.126v6.785c-.885-.953-1.802-1.637-2.737-2.098a6.967 6.967 0 0 0-2.032-.595 10.35 10.35 0 0 0-1.405-.091c-2.339 0-4.25.804-5.687 2.412-1.437 1.608-2.156 3.84-2.156 6.708 0 1.356.184 2.62.535 3.78.367 1.159.901 2.172 1.607 3.033a7.439 7.439 0 0 0 2.506 1.995c.964.46 2 .698 3.133.698.503 0 .993-.043 1.465-.132a5.76 5.76 0 0 0 .887-.211 7.628 7.628 0 0 0 2.003-1.01c.626-.447 1.24-1.028 1.878-1.726v.446c0 .848.216 1.488.629 1.95.412.446.964.683 1.604.683.626 0 1.178-.223 1.59-.653.413-.446.61-1.101.61-1.977V7.638c.002-.85-.18-1.505-.562-1.949Zm-4.739 18.715c-.413.862-.964 1.503-1.65 1.92a4.219 4.219 0 0 1 ...
# <svg height="1" id="preloader" viewbox="0 0 150 1" width="150">
# <path d="M0,0 L150,0" fill="none" id="loading-line-bkgd" stroke="#F3F2F1" stroke-width="150"></path>
# <style>
#                         #loading-line-main {
#                             stroke-dasharray: 150;
#                             stroke-dashoffset: 150;
#                         }
#                         @keyframes animateLine {
#                             to {
#                                 stroke-dashoffset: 0;
#                             }
#                         }
#                         #loading-line-main {
#                             animation: animateLine 2s linear infinite;
#                         }
#                     </style>
# <path d="M0,0 L150,0" fill="none" id="loading-line-main" stroke="#003A9B" stroke-width="20"></path>
# </svg>
# </div>
# </div>
# <script data-src="shim.1fda0d76e8ca51e8a649.js">
# (()=>{"use strict";var i={p:""};window&&window.mosaic&&window.mosaic.webpackPublicPath&&(i.p=window.mosaic.webpackPublicPath+"/"),window.mosaic=window.mosaic||{},window.mosaic.apiQueue=window.mosaic.apiQueue||[],window.mosaic.onMosaicApiReady=i=>{window.mosaic.apiQueue.push(i)},window.mosaic.loggingCallbacks=window.mosaic.loggingCallbacks||[],window.mosaic.onProviderBrowserEvent=i=>(window.mosaic.loggingCallbacks.push(i),{removeCallback:()=>{const o=window.mosaic.loggingCallbacks.indexOf(i);-1!==o&&window.mosaic.loggingCallbacks.splice(o,1)}})})();
# //# sourceMappingURL=shim.1fda0d76e8ca51e8a649.js.map</script><script data-src="SharedDepsShim.js">
# "use strict";(()=>{const e=window._INDEED=window._INDEED||{},o=e.shared=e.shared||{};o.v1||(o.v1={load:function(){for(var e=arguments.length,n=new Array(e),r=0;r<e;r++)n[r]=arguments[r];return new Promise(((e,r)=>{o.v1.load.q.push({args:n,resolve:e,reject:r})}))},initialize:e=>{o.v1.config||(o.v1.config=e,n(3))}},o.v1.load.q=[]);const n=e=>{if(o.v1.load.q){var r;const s=o.v1.config;let a=s.loadersUrl;const t=null!==(r=localStorage.getItem("shared-deps.branch"))&&void 0!==r?r:s.branch;t&&(a=a.replace("sharedDepsLoaders",`${t}/sharedDepsLoaders`));const c=document.createElement("script");c.async=!0,c.src=a,c.crossOrigin="anonymous",c.onerror=o=>{if(o instanceof ErrorEvent){const a=e-1;if(a>0)n(a);else{var r;const{error:e,message:n,filename:a,lineno:t,colno:c}=o,d=(null==e?void 0:e.name)||"SharedDepsShimLoaderError",i=(null==e?void 0:e.message)||n||"Failed to fetch & execute sharedDepsLoader",l=(null==e?void 0:e.toString())||`${d}: ${i}`,v=null===(r=(null==e?void 0:e.stack)||`event: ${a}:${t}:${c}\nonerror: ${(new Error).stack}`)||void 0===r?void 0:r.substring(0,1e3),m=document.createElement("script");m.async=!0,m.crossOrigin="anonymous",m.src=`${s.logRoute}&logType=${s.jsErrorLogType}&lth=${s.jsErrorLth}&name=${d}&message=${encodeURIComponent(i)}&toString=${encodeURIComponent(l)}&stack=${encodeURIComponent(v)}`,document.head.appendChild(m)}}},document.head.appendChild(c)}}})();</script><script>
# window._INDEED.shared.v1.initialize({ publicPath: "https://c03.s3.indeed.com/shared/", loadersUrl: "https://c03.s3.indeed.com/shared/sharedDepsLoadersV1.autoupgrade.js", shareScopes: ["react17", "react18"], groups: {}, logRoute: "https://t.indeed.com/signals/gnav/log?", jsErrorLogType: "gnavJSError", jsErrorLth: "6411ec182c6acd8714dc2d03716eed1d" });
# </script><link href="https://c03.s3.indeed.com/mosaic-common/dist/index.39fb594906966db1fba1.css?cacheKey=1" rel="stylesheet"/>
# <link href="https://c03.s3.indeed.com/mosaic-provider-reportcontent/dist/591.3654a31a0f78cd008eb4.css" rel="stylesheet"/>
# <link href="https://c03.s3.indeed.com/uip-micro-content-provider/dist/791.06d6ef6c09ed13870a6b.css" rel="stylesheet"/>
# <link href="https://c03.s3.indeed.com/mosaic-provider-jobalert/dist/832.d75e3c288f9098f7c0dc.css" rel="stylesheet"/>
# <link href="https://c03.s3.indeed.com/mosaic-provider-jobsearch-feedback/dist/112.31d6cfe0d16ae931b73c.css" rel="stylesheet"/>
# <link href="https://c03.s3.indeed.com/mosaic-provider-jobsearch-feedback/dist/513.a8bf454cd55b8441d718.css" rel="stylesheet"/>
# <link href="https://c03.s3.indeed.com/mosaic-provider-reportcontent/dist/182.5728b911d96b7caa2e49.css" rel="stylesheet"/>
# <link href="https://c03.s3.indeed.com/mosaic-provider-passport-intercept/dist/136.bb410b284bc19f21657a.css" rel="stylesheet"/>
# <link href="https://c03.s3.indeed.com/mosaic-provider-jobcards/dist/529.a977a2af9fefd40d437d.css" rel="stylesheet"/>
# <link href="https://c03.s3.indeed.com/mosaic-provider-rich-search/static/593.ec84c9279207d3631715.css" rel="stylesheet"/>
# <link href="https://c03.s3.indeed.com/mosaic-provider-jobalert/dist/352.47b7ae9413464237e7a7.css" rel="stylesheet"/><link href="https://c03.s3.indeed.com/mosaic-common/dist/index.39fb594906966db1fba1.css?cacheKey=1" rel="stylesheet"/>
# <link href="https://c03.s3.indeed.com/mosaic-provider-reportcontent/dist/591.3654a31a0f78cd008eb4.css" rel="stylesheet"/><style> #preLoadingIndicator { display: none; } </style>
# <style type="text/css">
#         .screenreader-text:focus {
#             height: auto;
#             width: auto;
#             opacity: 1;
#             position: static;
#             overflow: visible;
#         }
#     </style>
# <a class="screenreader-text" href="#gnav-header-end" id="skip-nav" style="color: black; position: absolute; width: 1px; height: 1px; opacity: 0; overflow: hidden;">
#         Lewati ke konten utama</a>
# <div class="mosaic-zone" id="mosaic-zone-ssrSerpModals"><div class="mosaic mosaic-provider-passport-intercept" id="mosaic-provider-passport-intercept"><div data-testid="passport-intercept-type-modal"></div></div></div><main class="is-i18n">
# <script>
#             !function(_){_.__JS_ERROR__=[],_.onerror=function(){_.__JS_ERROR__.push(Array.prototype.slice.call(arguments))}}(window);!function(r){const t={homepage:"mobtk",viewjob:"mobvjtk",viewjobJapan:"mobvjtk",serp:"mobtk",serpJapan:"mobtk"},n={homepage:"hp",viewjob:"vj",viewjobJapan:"vjjp",serp:"srch",serpJapan:"srchjp"},p=function(e){return t[e]},d=function(e){return n[e]},c=function(){var e=r.devicePixelRatio||1,e='"pixelRatio":'+e+',"scrWidth":'+Math.floor(r.screen.width*e)+',"scrHeight":'+Math.floor(r.screen.height*e);return r.screen.orientation&&(e+=',"scrOrientation":"'+(-1<r.screen.orientation.type.indexOf("portrait")?"portrait":"landscape")+'"'),e};r.logPageLoadInfo=function(e,t,n){if(Image){var o=d(e),a=p(e);if(o&&a){t=(a=t,'"eventName":"mobPageLoadInfo","type":"mobPageLoadInfo","pageId":"'+(t=e)+'","'+p(t)+'":"'+a+'","pageName":"'+d(t)+'"');n&&r.screen&&(t+=","+c());t="/m/rpc/frontendlogging?logType=trackEvent&moduleName=event&application=indeedmobile&pageId="+e+"&data="+encodeURIComponent("{"+t+"}").replace(/%20/g,"+");const i=new Image;i.src=t,i.height=i.width=0,i.height=i.width=1,i.style.display="none",i.ariaHidden=!0,i.alt=" ",i.setAttribute("aria-hidden","true"),document.body.appendChild(i)}}}}(window);!function(r){function t(t){for(var e=t.target;e&&e!==r.documentElement;){if("A"===e.tagName){var n=e.getAttribute("data-href");return void(null!==n&&(e.setAttribute("href",n),e.removeAttribute("data-href")))}e=e.parentNode}}r.addEventListener&&("ontouchstart"in r?r.addEventListener("touchstart",t):r.addEventListener("mousedown",t))}(document);
#
#             window._initialData={"apiPaths":{},"appCommonData":null,"appleSmartAppBannerAppsFlyerPingModel":null,"appliedRadius":0,"autoOpenJobAttributes":{"jobKey":"2cbeb6c3aa06ced0","from":"vjs","tk":"1hto33eifk12d800","extractTrackingUrls":[],"advn":"","adId":"","link":"\u002Frc\u002Fclk?jk=2cbeb6c3aa06ced0&bb=B8yOG_LhAnSJX5_6L9JMLG-CEWRhaKbPnBHkEMOhZEqKDQR2SbHv_vhBchkojXopZ7TZi0NuJXLxf6v9P1u00qql_eckTXGhzISEyHhlGCYT3fv-Iz-Ea1oEGaBdglWA&xkcb=SoCF67M3B4OCDsWcYB0LbzkdCdPP&fccid=80cc08f12ab939fd&vjs=3"},"autoOpenTwoPaneIsSponsored":false,"autoOpenTwoPaneJobKey":"2cbeb6c3aa06ced0","autoOpenTwoPaneViewjobResponse":{"status":"success","body":{"accountKey":null,"additionalLinksViewModel":{"careerGuideArticleLinks":[],"companySalaryLinks":[],"nearbyLocationLinks":[],"similarCategoryLinks":[],"similarJobTitleLinks":[]},"apiPaths":{},"appCommonData":null,"autoClickApply":false,"autocompleteEndpoint":"https:\u002F\u002Fautocomplete.indeed.com\u002Fapi\u002Fv0","base64EncodedJson":"...","baseInboxUrl":"https:\u002F\u002Finbox.indeed.com","baseUrl":"https:\u002F\u002Fid.indeed.com","benefitsModel":null,"callToInterviewButtonModel":null,"categorizedAttributesModel":null,"chatbotApplyButtonLinkModel":null,"clientsideProctorGroups":{"isHpSerpHideLoggedOutDislikeActive":false,"isMosaicJobDetailsActive":true,"clearResetString":false,"shouldDisableIAButtonBeforeReady":false,"isAssistantActive":false,"isMobVjAdTransparencyEUNewContentTest":false,"simpleVJImprove":true,"simple2Pane":true,"showSalaryGuide":false,"isMobVjShowHmInfoTstActive":false,"callToApplyStickyBelowApplyNow":false,"isMosaicAiAssistantEvaluateJobActive":false,"isMosaicAiAssistantSummarizeRequirementsActive":false,"shouldGateSaveJob":false,"callToApplyStickySideBySide":false,"connectionNavigator":false,"isSaveJobAppPromoActive":false,"isCommuteEstimateActive":false,"toastOnVJFromDC":false,"isConnectionNavigatorCallPrimary":true,"isMobVjSecondaryActionsProminenceActive":false,"isMosaicAiAssistantJobExplainerActive":false,"callButtonPrimaryApplySecondary":false,"isObfuscateApply":true},"cmiJobCategoryModel":null,"commuteInfoModel":null,"companyFollowFormModel":null,"companyTabModel":null,"contactPersonModel":null,"contextualSignInPassportURL":"https:\u002F\u002Fsecure.indeed.com\u002Faccount\u002Flogin?hl=in_ID&co=ID&continue=https%3A%2F%2Fid.indeed.com%2Fviewjob%3FcontinueUrl%3D%252Fjobs%253Fq%253Dfrontend%252Bdeveloper%2526start%253D10%2526from%253DsearchOnHP%2526l%253D%26from%3Dtp-semfirstjob%26viewtype%3Dembedded%26jk%3D2cbeb6c3aa06ced0%26tk%3D1hto33eifk12d800%26xkcb%3DSoCF67M3B4OCDsWcYB0LbzkdCdPP","country":"ID","cssResetProviders":{"mosaic-provider-reportcontent":false,"js-match-insights-provider":false,"js-match-insights-provider-job-details":false},"ctaEnticer":null,"ctk":"1hto33ehqk12d800","dcmModel":{"category":"jobse0","source":"8232301","type":"organic"},"desktop":true,"dgToken":"D7AD1D7DAC413E22109214B1DF7437FA","dislikeFrom2paneEnabled":true,"downloadAppButtonModel":null,"dsanr":false,"employerResponsiveCardModel":null,"from":"tp-semfirstjob","globalnavFooterHTML":"","globalnavHeaderHTML":"","highQualityMarketplace":null,"highQualityMarketplaceHiringManager":null,"hiringInsightsModel":{"age":"30+ hari yang lalu","employerLastReviewed":null,"employerResponsiveCardModel":null,"numOfCandidates":null,"postedToday":false,"recurringHireText":null,"urgentlyHiringModel":null},"hostQueryExecutionResult":{"data":{"jobData":{"__typename":"JobDataPayload","results":[{"__typename":"JobDataResult","job":{"__typename":"Job","key":"2cbeb6c3aa06ced0","title":"IT: Frontend Developer","sourceEmployerName":"PCS Group","datePublished":1707112800000,"expired":false,"language":"en","normalizedTitle":"front end developer","refNum":"237912","expirationDate":1746684000000,"source":{"__typename":"JobSource","key":"AAAAAY5oTkGMMn5XbcVwnjda7iQ+IQBTUZAWrNexapKAVwJy6tFAeg==","name":"Kalibrr"},"feed":{"__typename":"JobFeed","key":"AAAAASLhSk80WScFbqxz1APzfJRiM3YNX\u002FUwVqZX+SYsxFK9FJBbRw==","is ...
#             window.addEventListener('pageshow', function(e) {
#                 if (window.performance && typeof window.performance.getEntriesByType === 'function') {
#                     const perfEntries = window.performance.getEntriesByType('navigation');
#                     if (perfEntries && perfEntries.length > 0 && perfEntries[0].type === 'back_forward') {
#                         window['_bk'] = '1';
#                     }
#                 }
#                 if (e.persisted) {
#                     window['_bk'] = '1';
#                 }
#             });
#         </script>
# <div id="jobsearch-Main">
# <div class="mosaic-zone" id="mosaic-aboveSerpNav"></div><style data-emotion="css kyg8or">.css-kyg8or{box-sizing:border-box;margin:0;min-width:0;}</style><span class="css-kyg8or eu4oa1w0" id="m-gnav-header"><script id="_indeed_gnav_config" type="application/json">{"isEmployer":false,"isMobile":false,"desktopPageLinks":[{"text":"Beranda","href":"https://id.indeed.com/","dataHref":"https://id.indeed.com/?from=gnav-jobsearch--indeedmobile","isHighlighted":true,"dataGnavElementName":"FindJobs"},{"text":"Ulasan Perusahaan","href":"https://id.indeed.com/companies","dataHref":"https://id.indeed.com/companies?from=gnav-jobsearch--indeedmobile","isHighlighted":false,"dataGnavElementName":"CompanyReviews"},{"text":"Cari Info Gaji","href":"https://id.indeed.com/career/salaries","dataHref":"https://id.indeed.com/career/salaries?from=gnav-jobsearch--indeedmobile","isHighlighted":false,"dataGnavElementName":"FindSalaries"}],"skipNavLinkModel":{"href":"#gnav-header-end","text":"Lewati ke konten utama","targetText":"Awal konten utama","dataGnavElementName":"SkipNav"},"variantToggleLink":{"text":"Perusahaan: Pasang Lowongan Kerja","href":"https://id.indeed.com/hire?co=ID\u0026hl=in","dataHref":"https://id.indeed.com/hire?co=ID\u0026hl=in\u0026from=gnav-menu-jobsearch--indeedmobile\u0026ikw=gnav-header-hire\u0026isid=employerlink-ID","dataGnavElementName":"EmployersPostJob"},"country":"ID","logoHref":"/?from=gnav-jobsearch--indeedmobile","logoName":"aurora","appName":"jobsearch--indeedmobile","shouldReduceRightMargin":false,"secondaryLogoName":"ukraine_support","secondaryLogoImageUrl":"https://c03.s3.indeed.com/dist/header/ukraine_support.7ad2b5d444bc427dbc5d.png","secondaryLogoTooltip":"","secondaryLogoAltText":"","secondaryLogoAriaHidden":true,"secondaryLogoLinkUrl":"","inboxApiHref":"https://messages.indeed.com/messaging/jobseekers/v2/summary?from=gnav-util-jobsearch--indeedmobile\u0026gnavTK=1hto33en1j6q3801\u0026tk=1hto33eifk12d800\u0026co=ID\u0026hl=in\u0026clientApp=GNAV","inboxHref":"https://messages.indeed.com?from=gnav-util-jobsearch--indeedmobile\u0026gnavTK=1hto33en1j6q3801\u0026tk=1hto33eifk12d800\u0026co=ID\u0026hl=in","logRoute":"https://t.indeed.com/signals/gnav/log?from=jobsearch--indeedmobile-serpglobal\u0026parentLogId=1hto33en1j6q3801\u0026hostAppTk=1hto33eifk12d800","inboxLogTuple":"gnavInbox:12140b7982d032f1660f59e3e976c72d","isShowInboxIcon":false,"selectedIcon":"","shouldReduceNavIconMargins":false,"oneGraphBaseUrl":"https://apis.indeed.com/graphql","oneGraphApiKeyJobSeeker":"0749794b608bca655de91ae7abe1ef7ec2fb3717c107ccbe352b6f46d091ec28","inboxLogType":"gnavInbox","inboxLth":"12140b7982d032f1660f59e3e976c72d","promptInterestStrings":{"promptInterestModalTitleText":"Are you still interested in this job opportunity?","promptInterestModalReplyText":"Yes, reply now","promptInterestModalDismissText":"I'm no longer interested","defaultDeclineMessage":"Thanks for the opportunity, but I'm no longer interested at this time. I'll reach back out if things change.","promptSendDeclineMessageModalTitleText":"We'll send this message to the employer","promptSendDeclineMessageModalSendButtonText":"Send this decline message","promptSendDeclineMessageModalEditButtonText":"Edit message"},"notificationApiHref":"https://id.indeed.com/notifications/api/1/getNotificationsCount?client=gnav\u0026from=gnav-util-jobsearch--indeedmobile\u0026gnavTK=1hto33en1j6q3801\u0026tk=1hto33eifk12d800","notificationHref":"https://id.indeed.com/notifications?from=gnav-util-jobsearch--indeedmobile\u0026gnavTK=1hto33en1j6q3801\u0026tk=1hto33eifk12d800\u0026hl=in","isShowNotificationIcon":false,"notificationLogType":"gnavNotification","notificationLth":"6d669dfa33371660f3e683b38b9f3ddc","myjobsApiHref":"","myjobsHref":"https://myjobs.indeed.com?from=gnav-util-jobsearch--indeedmobile\u0026gnavTK=1hto33en1j6q3801\u0026tk=1hto33eifk12d800\u0026co=ID\u0026hl=in","myjobsLogTuple":"gnavMyjobs:5d9eaad2bbc69a980218f0a8aa03ae77","isMyjobsTestActive":false,"isShowMyjobsIco ...
# <script>
#             if (window.performance !== undefined && performance.mark !== undefined) {
#                 performance.mark('gnavRenderBlockingCSSHeader:start');
#             }
#         </script><link crossorigin="anonymous" href="https://c03.s3.indeed.com/dist/react18/header/jobseekerHeader.94e87003e1abd31839ca.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://fonts.gstatic.com/" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://c03.s3.indeed.com/fonts/v1/indeedsans.css" rel="stylesheet" type="text/css"/>
# <script>
#             if (window.performance !== undefined && performance.mark !== undefined && performance.measure !== undefined) {
#                 performance.mark('gnavRenderBlockingCSSHeader:end');
#                 performance.measure('gnavRenderBlockingCSSHeader', 'gnavRenderBlockingCSSHeader:start', 'gnavRenderBlockingCSSHeader:end');
#             }
#         </script><nav aria-label="Utama" class="gnav" id="gnav-main-container"><style>.jobsearch-ResumeFooter-container, .jobsearch-FooterResume { display: none; }</style><div data-gnav-region="Main"><style data-emotion="gnav-header 1gheiwz">#gnav-main-container.gnav .gnav-header-1gheiwz{display:flex;box-sizing:border-box;margin:0;min-width:0;width:100%;min-height:3.25rem;background-color:#ffffff;justify-content:space-between;border-bottom-width:0.0625rem;border-bottom-color:#e4e2e0;border-bottom-style:none;}@media screen and (min-width: 62em){#gnav-main-container.gnav .gnav-header-1gheiwz{border-bottom-style:solid;}}</style><div class="gnav-header-1gheiwz e37uo190"><div class="css-wnhbdt e37uo190"><style data-emotion="gnav-header hczdj6">#gnav-main-container.gnav .gnav-header-hczdj6{border-radius:0;color:#2557a7;font-family:"Noto Sans","Helvetica Neue","Helvetica","Arial","Liberation Sans","Roboto","Noto",sans-serif;text-decoration:none;transition:border-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),background-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),opacity 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-style 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-width 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-radius 200ms cubic-bezier(0.645, 0.045, 0.355, 1),box-shadow 200ms cubic-bezier(0.645, 0.045, 0.355, 1),color 200ms cubic-bezier(0.645, 0.045, 0.355, 1);border-bottom:0.0625rem solid;cursor:pointer;color:#2d2d2d;display:inline-flex;align-items:center;height:3rem;margin:0.125rem 0.75rem 0.125rem 1rem;margin-right:1rem;border-bottom:none;}#gnav-main-container.gnav .gnav-header-hczdj6:hover{color:#164081;}#gnav-main-container.gnav .gnav-header-hczdj6:active{color:#0d2d5e;}#gnav-main-container.gnav .gnav-header-hczdj6:focus{outline:none;border-bottom:0.0625rem solid;border-bottom-color:transparent;border-radius:0.25rem;box-shadow:0 0 0 0.0625rem;}#gnav-main-container.gnav .gnav-header-hczdj6:focus:not([data-focus-visible-added]){box-shadow:none;border-bottom:0.0625rem solid;border-radius:0;}#gnav-main-container.gnav .gnav-header-hczdj6:visited{color:#2557a7;}#gnav-main-container.gnav .gnav-header-hczdj6:hover,#gnav-main-container.gnav .gnav-header-hczdj6:active{color:#164081;}@media (prefers-reduced-motion: reduce){#gnav-main-container.gnav .gnav-header-hczdj6{transition:none;}}#gnav-main-container.gnav .gnav-header-hczdj6:focus:active:not([data-focus-visible-added]){box-shadow:none;border-bottom:0.0625rem solid;border-radius:0;}#gnav-main-container.gnav .gnav-header-hczdj6:hover{color:#2d2d2d;}@media screen and (min-width: 62em){#gnav-main-container.gnav .gnav-header-hczdj6{height:1.75rem;margin:0;margin-right:0;padding-left:1.5rem;padding-right:0.75rem;padding-top:1.375rem;padding-bottom:1.375rem;width:7rem;}}#gnav-main-container.gnav #gnav-main-container.gnav .gnav-header-hczdj6:focus,#gnav-main-container.gnav #gnav-main-container.gnav .gnav-header-hczdj6:focus:not([data-focus-visible-added]){border-bottom:none;}</style><a aria-label="Halaman Depan Indeed" class="gnav-Logo gnav-header-hczdj6 e19afand0" data-gnav-element-name="Logo" href="/?from=gnav-jobsearch--indeedmobile" id="indeed-globalnav-logo"><div aria-hidden="true" class="gnav-Logo-icon"><svg aria-hidden="true" fill="none" focusable="false" height="20" viewbox="0 0 75 20" width="75" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M74.613 3.458c-.265-.297-.62-.448-1.1-.448-.48 0-.846.159-1.101.487-.255.317-.387.793-.387 1.417v4.524c-.59-.636-1.203-1.092-1.825-1.399a4.568 4.568 0 0 0-1.356-.397 6.917 6.917 0 0 0-.937-.06c-1.559 0-2.822.536-3.791 1.608-.958 1.072-1.438 2.56-1.438 4.472 0 .904.123 1.747.367 2.52.246.772.59 1.448 1.06 2.022a4.975 4.975 0 0 0 1.67 1.33 4.766 4.766 0 0 0 2.089.465c.345 0 .672-.029.977-.088.205-.03.397-.08.592-.14a5.086 5.086 0 0 0 1.335-.674 7.8 7.8 0 0 0 1.253-1.15v.297c0 .565.143.992.418 1.3.286.297.643.455 1.07.455.438 0 .7 ...
# "use strict";(()=>{const e=window._INDEED=window._INDEED||{},o=e.shared=e.shared||{};o.v1||(o.v1={load:function(){for(var e=arguments.length,n=new Array(e),r=0;r<e;r++)n[r]=arguments[r];return new Promise(((e,r)=>{o.v1.load.q.push({args:n,resolve:e,reject:r})}))},initialize:e=>{o.v1.config||(o.v1.config=e,n(3))}},o.v1.load.q=[]);const n=e=>{if(o.v1.load.q){var r;const s=o.v1.config;let a=s.loadersUrl;const t=null!==(r=localStorage.getItem("shared-deps.branch"))&&void 0!==r?r:s.branch;t&&(a=a.replace("sharedDepsLoaders",`${t}/sharedDepsLoaders`));const c=document.createElement("script");c.async=!0,c.src=a,c.crossOrigin="anonymous",c.onerror=o=>{if(o instanceof ErrorEvent){const a=e-1;if(a>0)n(a);else{var r;const{error:e,message:n,filename:a,lineno:t,colno:c}=o,d=(null==e?void 0:e.name)||"SharedDepsShimLoaderError",i=(null==e?void 0:e.message)||n||"Failed to fetch & execute sharedDepsLoader",l=(null==e?void 0:e.toString())||`${d}: ${i}`,v=null===(r=(null==e?void 0:e.stack)||`event: ${a}:${t}:${c}\nonerror: ${(new Error).stack}`)||void 0===r?void 0:r.substring(0,1e3),m=document.createElement("script");m.async=!0,m.crossOrigin="anonymous",m.src=`${s.logRoute}&logType=${s.jsErrorLogType}&lth=${s.jsErrorLth}&name=${d}&message=${encodeURIComponent(i)}&toString=${encodeURIComponent(l)}&stack=${encodeURIComponent(v)}`,document.head.appendChild(m)}}},document.head.appendChild(c)}}})();
# window._INDEED.shared.v1.initialize({"publicPath":"https://c03.s3.indeed.com/shared/","loadersUrl":"https://c03.s3.indeed.com/shared/sharedDepsLoadersV1.autoupgrade.js","shareScopes":["react18"],"groups":{},"logRoute":"https://t.indeed.com/signals/gnav/log?from=jobsearch--indeedmobile-serpglobal&parentLogId=1hto33en1j6q3801&hostAppTk=1hto33eifk12d800","jsErrorLogType":"gnavJSError","jsErrorLth":"6411ec182c6acd8714dc2d03716eed1d"});
# </script><script>(() => {
# var callFnWhenReady = window._INDEED && window._INDEED.shared && window._INDEED.shared.v1 ? (fn) => fn() : (fn) => window.addEventListener('onSharedDepsLoadersV1Available', fn, { once: true });
# callFnWhenReady(() => window._INDEED.shared.v1.load("module", {"urls":["https://c03.s3.indeed.com/dist/react18/header/remoteEntry.6a7aa3c35b674de33718.js"],"container":"gnavHeaderModule","module":"./jobseekerHeader","shareScope":"react18","afterEvent":"DOMContentLoaded"}).catch(()=>null));
# })();</script><div id="gnav-script-contents">
# <script>
#             window.signals_transport = window.signals_transport || {
#                 emitSignal: function(data){
#                     window.signals_transport_tmp = window.signals_transport_tmp || [];
#                     if (window.signals_transport_tmp.length < 1000) {
#                         window.signals_transport_tmp.push(data);
#                     }
#                 }
#             };
#         </script>
# </div></span><style data-emotion="css-global kojvcn">body{margin:0;font-family:"Noto Sans","Helvetica Neue",Helvetica,Arial,sans-serif;font-size:0.875rem;letter-spacing:0;line-height:1.43;font-weight:400;-webkit-text-size-adjust:100%;}body:root[lang='ja'] body{font-family:"Noto Sans CJK JP","Noto Sans",Noto,"Hiragino Sans","Helvetica Neue",Helvetica,Arial,"Liberation Sans",Roboto,sans-serif;}body .mobAuroraTst div .whitePromo .promoAppInfo .resumePromoHeader{color:#2d2d2d;}</style><div class="css-kyg8or eu4oa1w0" id="jobsearch-JapanPage"><style data-emotion="css 1wfd0c">.css-1wfd0c{box-sizing:border-box;margin:0;min-width:0;background-color:#ffffff;word-break:break-word;word-wrap:break-word;}@media screen and (min-width: 600px){body:not(.is-desktop) #jobsearch-Main .css-1wfd0c{max-width:736px;margin:0 auto;}}</style><div class="jobsearch-JapanPageLayout is-i18n css-1wfd0c eu4oa1w0"><div class="mosaic-zone" id="mosaic-belowNav"></div><style data-emotion="css 1ie6qsd">.css-1ie6qsd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;margin:0;min-width:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;position:relative;background-color:#ffffff;}.is-desktop .css-1ie6qsd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;padding-top:0.75rem;padding-left:0;padding-right:0;padding-bottom:1rem;border-bottom:1px solid #e4e2e0;width:100%;}.is-desktop .css-1ie6qsd--hideBottomBorder{border-bottom:none;}@media (max-width: 768px){.is-desktop .css-1ie6qsd{border-bottom:none;}}.is-desktop .css-1ie6qsd .jobsearch-RichSearchBody{margin:0 auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}@media screen and (max-width: 959px){.is-desktop .css-1ie6qsd .jobsearch-RichSearchBody{width:auto;margin:0 1rem;}}@media screen and (min-width: 960px) and (max-width: 1279px){.is-desktop .css-1ie6qsd .jobsearch-RichSearchBody{width:55rem;}}@media screen and (min-width: 1280px) and (max-width: 1359px){.is-desktop .css-1ie6qsd .jobsearch-RichSearchBody{width:58.75rem;}}@media screen and (min-width: 1360px) and (max-width: 1439px){.is-desktop .css-1ie6qsd .jobsearch-RichSearchBody{width:60.3rem;}}@media screen and (min-width: 1440px) and (max-width: 1739px){.is-desktop .css-1ie6qsd .jobsearch-RichSearchBody{width:64rem;}}@media screen and (min-width: 1740px){.is-desktop .css-1ie6qsd .jobsearch-RichSearchBody{width:76.45rem;}}.is-desktop .css-1ie6qsd .MosaicProviderRichSearchDaemon{width:100%;padding-top:0.5rem;}.css-1ie6qsd .yosegi-QueryReplace{background-color:#ffffff;}.css-1ie6qsd .yosegi-QueryReplace-link{color:#2557a7;-webkit-text-decoration:none;text-decoration:none;border-bottom:1px solid;border-color:#2557a7;}</style><div class="jobsearch-RichSearch css-1ie6qsd e37uo190"><div class="jobsearch-RichSearchBody"><div class="mosaic MosaicProviderRichSearchDaemon" id="MosaicProviderRichSearchDaemon"><div class="dd-privacy-allow" role="search"><div class="yosegi-InlineWhatWhere css-kyg8or eu4oa1w0"><form action="/jobs?q=frontend%20developer&amp;l=&amp;from=searchOnDesktopSerp" class="yosegi-InlineWhatWhere-form" id="jobsearch" method="get"><style data-emotion="css 1ctkzr6">.css-1ctkzr6{box-sizing:border-box;margin:0;min-width:0;position:relative;z-index:4;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-right:auto;margin-left:auto;margin-top:0;margin-bottom:1.5rem;border-radius:0.5rem;border:solid 1px;border-color:#949494;box-shadow:0 0.5rem 1rem rgba(45, 45, 45, 0.12),0 0.25rem 0.5rem rgba(45, 45, 45, 0.16),0 0 0.125rem rgba(45, 45, 45, 0.2);-webkit- ...
# <li style="margin-bottom:0px;">Determining the structure and design of web pages.</li>
# <li style="margin-bottom:0px;">Ensuring user experience determines design choices.</li>
# <li>Developing features to enhance the user experience.</li>
# </ul></div><span class="css-qvloho eu4oa1w0" data-testid="myJobsStateDate"><span class="css-10pe3me eu4oa1w0">Posted</span>Diposting 30+ hari yang lalu</span><span class="css-opxvw7 eu4oa1w0">·</span><button aria-expanded="false" class="sl resultLink css-ff8z8x eu4oa1w0" data-testid="more_links_button" type="button">lebih lanjut...</button></div><div class="css-6iwpn6 eu4oa1w0"><div class="result-tab css-9pzb1s eu4oa1w0"><div class="css-ldptw eu4oa1w0" data-testid="more_links"><button aria-label="Close" class="css-1dvqyzs eu4oa1w0" title="Close" type="button"></button><ul><li><span class="mat">Lihat semua lowongan <a class="css-1f8zkg3 e19afand0" href="/q-pcs-group-lowongan.html">lowongan kerja PCS Group, PCS Group jobs</a> di <a class="css-1f8zkg3 e19afand0" href="/l-tangerang-lowongan.html">Tangerang jobs</a> - <a class="css-1f8zkg3 e19afand0" href="/q-front-end-developer-l-tangerang-lowongan.html">lowongan kerja Front End Developer di Tangerang, Front End Developer jobs in Tangerang</a></span></li><li><span class="mat">Pencarian Gaji: <style data-emotion="mosaic-provider-jobcards 1f8zkg3">.mosaic-provider-jobcards-1f8zkg3{border-radius:0;color:#2557a7;font-family:"Noto Sans","Helvetica Neue","Helvetica","Arial","Liberation Sans","Roboto","Noto",sans-serif;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:border-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),background-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),opacity 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-style 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-width 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-radius 200ms cubic-bezier(0.645, 0.045, 0.355, 1),box-shadow 200ms cubic-bezier(0.645, 0.045, 0.355, 1),color 200ms cubic-bezier(0.645, 0.045, 0.355, 1);transition:border-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),background-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),opacity 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-style 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-width 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-radius 200ms cubic-bezier(0.645, 0.045, 0.355, 1),box-shadow 200ms cubic-bezier(0.645, 0.045, 0.355, 1),color 200ms cubic-bezier(0.645, 0.045, 0.355, 1);border-bottom:1px solid;cursor:pointer;}.mosaic-provider-jobcards-1f8zkg3:hover{color:#164081;}.mosaic-provider-jobcards-1f8zkg3:active{color:#0d2d5e;}.mosaic-provider-jobcards-1f8zkg3:focus{outline:none;border-bottom:1px solid;border-bottom-color:transparent;border-radius:4px;box-shadow:0 0 0 1px;}.mosaic-provider-jobcards-1f8zkg3:focus:not([data-focus-visible-added]){box-shadow:none;border-bottom:1px solid;border-radius:0;}.mosaic-provider-jobcards-1f8zkg3:visited{color:#2557a7;}.mosaic-provider-jobcards-1f8zkg3:hover,.mosaic-provider-jobcards-1f8zkg3:active{color:#164081;}@media (prefers-reduced-motion: reduce){.mosaic-provider-jobcards-1f8zkg3{-webkit-transition:none;transition:none;}}.mosaic-provider-jobcards-1f8zkg3:focus:active:not([data-focus-visible-added]){box-shadow:none;border-bottom:1px solid;border-radius:0;}</style><a class="mosaic-provider-jobcards-1f8zkg3 e19afand0" href="/career/front-end-developer/salaries/Tangerang?campaignid=serp-more&amp;fromjk=2cbeb6c3aa06ced0&amp;from=serp-more">Gaji IT: Frontend Developer di Tangerang</a></span></li></ul></div></div></div></div></div><div class="ctaContainer"></div><div aria-live="polite"></div></div></div></div></div></div><span aria-live="polite" class="visually-hidden css-10pe3me eu4oa1w0"></span><!--/$--></li><li class="css-5lfssm eu4oa1w0"><!--$--><div class="cardOutline tapItem dd-privacy-allow result job_9f086f134bfeec1f resultWithShelf sponTapItem desktop css-yria2i eu4oa1w0"><div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div  ...
# <li style="margin-bottom:0px;">Next.js Rest API API OOP HTML JavaScript React CSS.</li>
# <li>Write website code with programming languages such as HTML, CSS, and JavaScript.</li>
# </ul></div><span class="css-qvloho eu4oa1w0" data-testid="myJobsStateDate"><span class="css-10pe3me eu4oa1w0">Posted</span>Diposting 4 hari yang lalu</span><span class="css-opxvw7 eu4oa1w0">·</span><button aria-expanded="false" class="sl resultLink css-ff8z8x eu4oa1w0" data-testid="more_links_button" type="button">lebih lanjut...</button></div><div class="css-6iwpn6 eu4oa1w0"><div class="result-tab css-9pzb1s eu4oa1w0"><div class="css-ldptw eu4oa1w0" data-testid="more_links"><button aria-label="Close" class="css-1dvqyzs eu4oa1w0" title="Close" type="button"></button><ul><li><span class="mat">Lihat semua lowongan <a class="css-1f8zkg3 e19afand0" href="/q-nodeflair-lowongan.html">lowongan kerja NodeFlair, NodeFlair jobs</a> di <a class="css-1f8zkg3 e19afand0" href="/l-indonesia-lowongan.html">Indonesia jobs</a> - <a class="css-1f8zkg3 e19afand0" href="/q-front-end-developer-l-indonesia-lowongan.html">lowongan kerja Front End Developer di Indonesia, Front End Developer jobs in Indonesia</a></span></li><li><span class="mat">Pencarian Gaji: <a class="mosaic-provider-jobcards-1f8zkg3 e19afand0" href="/career/front-end-developer/salaries?campaignid=serp-more&amp;fromjk=9f086f134bfeec1f&amp;from=serp-more">Gaji Frontend Engineer di Indonesia</a></span></li></ul></div></div></div></div></div><div class="ctaContainer"></div><div aria-live="polite"></div></div></div></div></div></div><span aria-live="polite" class="visually-hidden css-10pe3me eu4oa1w0"></span><!--/$--></li><li class="css-5lfssm eu4oa1w0"><!--$--><div class="cardOutline tapItem dd-privacy-allow result job_448dc221391d8499 resultWithShelf sponTapItem desktop css-yria2i eu4oa1w0"><div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div class="slider_item css-mk9n32 eu4oa1w0" data-testid="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><div class="css-dekpa e37uo190"><h2 class="jobTitle css-198pbd eu4oa1w0" tabindex="-1"><a aria-label="detail lengkap Frontend Developer" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="448dc221391d8499" data-mobtk="1hto33eifk12d800" href="/rc/clk?jk=448dc221391d8499&amp;bb=B8yOG_LhAnSJX5_6L9JMLH0KP4pcIRQziGNSqghrvK5MpGiajULhyaWgMo1KVF84qEf_bhu52vfJGSHzdLSgPk5KbXxTp64CleD8EohnZGxTkP9Qf0WbX1Ep3lYu_I4t&amp;xkcb=SoCs67M3B4OCDsWcYB0JbzkdCdPP&amp;fccid=e105dccfbfdf6791&amp;vjs=3" id="job_448dc221391d8499" role="button"><span id="jobTitle-448dc221391d8499" title="Frontend Developer">Frontend Developer</span></a></h2><div class="css-1hlnck6 e37uo190"></div></div><div class="company_location css-17fky0v e37uo190"><div data-testid="timing-attribute"><span class="css-92r8pb eu4oa1w0" data-testid="company-name">Cybertrend Intrabuana</span><div class="css-1p0sjhy eu4oa1w0" data-testid="text-location">Jakarta</div></div></div><div class="jobMetaDataGroup css-pj786l eu4oa1w0"><div class="heading6 error-text tapItem-gutter"></div></div></td><td class="css-biqn32 eu4oa1w0"><style data-emotion="mosaic-provider-jobcards-global 1r54ni4">:root{--reach-menu-button:1;}</style><button aria-haspopup="true" aria-label="Job actions for Frontend Developer is collapsed" class="e8ju0x51 mosaic-provider-jobcards-1kkwgax ex6cvhv1" data-reach-menu-button="" id="menu-button--jobActionMenu-448dc221391d8499" title="More" type="button"><svg aria-hidden="true" class="mosaic-provider-jobcards-1luvpuv eac13zx0" fill="currentColor" focusable="false" role="img" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 3c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 7c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></button></td></tr></tbody></table><div class="css-1u8dvic eu4oa1w0" role="presentation"><div class="underShelfFoo ...
# <li style="margin-bottom:0px;">Experience with <b>frontend</b> frameworks such as React, Angular, or Vue.js.</li>
# <li>A Bachelor's degree in Computer Science, Software Engineering, or a related field.</li>
# </ul></div><span class="css-qvloho eu4oa1w0" data-testid="myJobsStateDate"><span class="css-10pe3me eu4oa1w0">Posted</span>Diposting 30+ hari yang lalu</span><span class="css-opxvw7 eu4oa1w0">·</span><button aria-expanded="false" class="sl resultLink css-ff8z8x eu4oa1w0" data-testid="more_links_button" type="button">lebih lanjut...</button></div><div class="css-6iwpn6 eu4oa1w0"><div class="result-tab css-9pzb1s eu4oa1w0"><div class="css-ldptw eu4oa1w0" data-testid="more_links"><button aria-label="Close" class="css-1dvqyzs eu4oa1w0" title="Close" type="button"></button><ul><li><span class="mat">Lihat semua lowongan <a class="css-1f8zkg3 e19afand0" href="/q-cybertrend-intrabuana-lowongan.html">lowongan kerja Cybertrend Intrabuana, Cybertrend Intrabuana jobs</a> di <a class="css-1f8zkg3 e19afand0" href="/l-jakarta-lowongan.html">Jakarta jobs</a> - <a class="css-1f8zkg3 e19afand0" href="/q-front-end-developer-l-jakarta-lowongan.html">lowongan kerja Front End Developer di Jakarta, Front End Developer jobs in Jakarta</a></span></li><li><span class="mat">Pencarian Gaji: <a class="mosaic-provider-jobcards-1f8zkg3 e19afand0" href="/career/front-end-developer/salaries/Jakarta?campaignid=serp-more&amp;fromjk=448dc221391d8499&amp;from=serp-more">Gaji Frontend Developer di Jakarta</a></span></li></ul></div></div></div></div></div><div class="ctaContainer"></div><div aria-live="polite"></div></div></div></div></div></div><span aria-live="polite" class="visually-hidden css-10pe3me eu4oa1w0"></span><!--/$--></li><li class="css-5lfssm eu4oa1w0"><!--$--><div class="cardOutline tapItem dd-privacy-allow result job_43c9697a7f48079b resultWithShelf sponTapItem desktop css-yria2i eu4oa1w0"><div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div class="slider_item css-mk9n32 eu4oa1w0" data-testid="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><div class="css-dekpa e37uo190"><h2 class="jobTitle css-198pbd eu4oa1w0" tabindex="-1"><a aria-label="detail lengkap Frontend Developer" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="43c9697a7f48079b" data-mobtk="1hto33eifk12d800" href="/rc/clk?jk=43c9697a7f48079b&amp;bb=B8yOG_LhAnSJX5_6L9JMLIW1qSJZF701EjERjOUJGqc10fISWk1Zk5QiElmd4HxAy73tIX0dQeutXbROHJnudYDw9DkviDkia28VQ5R7h_mBsA22_Ll5rplRPAMoXlne&amp;xkcb=SoAY67M3B4OCDsWcYB0IbzkdCdPP&amp;fccid=a5d4bf2c93c69c32&amp;vjs=3" id="job_43c9697a7f48079b" role="button"><span id="jobTitle-43c9697a7f48079b" title="Frontend Developer">Frontend Developer</span></a></h2><div class="css-1hlnck6 e37uo190"></div></div><div class="company_location css-17fky0v e37uo190"><div data-testid="timing-attribute"><span class="css-92r8pb eu4oa1w0" data-testid="company-name">Vox Teneo</span><div class="css-1p0sjhy eu4oa1w0" data-testid="text-location">Indonesia</div></div></div><div class="jobMetaDataGroup css-pj786l eu4oa1w0"><div class="heading6 error-text tapItem-gutter"></div></div></td><td class="css-biqn32 eu4oa1w0"><style data-emotion="mosaic-provider-jobcards-global 1r54ni4">:root{--reach-menu-button:1;}</style><button aria-haspopup="true" aria-label="Job actions for Frontend Developer is collapsed" class="e8ju0x51 mosaic-provider-jobcards-1kkwgax ex6cvhv1" data-reach-menu-button="" id="menu-button--jobActionMenu-43c9697a7f48079b" title="More" type="button"><svg aria-hidden="true" class="mosaic-provider-jobcards-1luvpuv eac13zx0" fill="currentColor" focusable="false" role="img" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 3c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 7c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></svg></button></td></tr></tbody></table><div class="css-1u8dvic eu4oa1w0" role="presentation"> ...
# <li style="margin-bottom:0px;">We are looking for experienced and self-driven <b>Frontend</b> developers.</li>
# <li>Coding applications features according to the business requirements.</li>
# ...
#     window.mosaic.providerData["MosaicProviderRichSearchDaemon"]={"allowEmptyWhatWhereSearch":true,"autoCompleteFrom":"serp","hostLocation":"DESKTOP","isDesktop":true,"isShowRemoteSearchCallout":false,"isUnifiedFilters":false,"isUseToast":false,"prefillExtendedRecentSearchParams":false,"proctorGroups":{"acme_desktop_company_serp_mode_tst":{"name":"","value":-1},"acme_toggle_cjs_tst":{"name":"","value":1},"mob_unified_filters_tst":{"name":"","value":-1},"yosegi_whatwhere_a11y_placeholder_tst":{"name":"","value":-1},"jsj_findjobs_cta_tst":{"name":"","value":-1},"desktop_multiselect_filter_tst":{"name":"","value":1},"yosegi_collapse_filters_tst":{"name":"","value":-1},"jsj_yosegi_sr_nav_headings_tst":{"name":"","value":-1},"jsj_whatwherebtns_searchoverlay_tst":{"name":"","value":-1},"ibu_india_suburb_popularity_tst":{"name":"","value":1}},"richSearchComponentModel":{"accountKey":"","allowFieldSearch":false,"apiPaths":{"getGeoHierarchy":"\u002Fm\u002Frpc\u002Fgeohierarchy?mobtk=1hto33eifk12d800"},"autofocusWhatbox":false,"companyJobSearchQuery":"","companyNameInQuery":"","country":"ID","ctk":"1hto33ehqk12d800","dynFiltersModel":{"filters":[{"dataType":"STATIC","filterName":"dateposted","noOptionValMap":{"fromage":""},"options":[{"@class":"com.indeed.yosegi.model.dynamicfilters.view.ImmutableNoCountBucketOption","label":"24 jam terakhir","paramValMap":{"fromage":"1"},"selected":false,"type":"noCountBucket","url":"\u002Fjobs?q=frontend+developer&fromage=1"},{"@class":"com.indeed.yosegi.model.dynamicfilters.view.ImmutableNoCountBucketOption","label":"3 hari terakhir","paramValMap":{"fromage":"3"},"selected":false,"type":"noCountBucket","url":"\u002Fjobs?q=frontend+developer&fromage=3"},{"@class":"com.indeed.yosegi.model.dynamicfilters.view.ImmutableNoCountBucketOption","label":"7 hari terakhir","paramValMap":{"fromage":"7"},"selected":false,"type":"noCountBucket","url":"\u002Fjobs?q=frontend+developer&fromage=7"},{"@class":"com.indeed.yosegi.model.dynamicfilters.view.ImmutableNoCountBucketOption","label":"14 hari terakhir","paramValMap":{"fromage":"14"},"selected":false,"type":"noCountBucket","url":"\u002Fjobs?q=frontend+developer&fromage=14"}],"presentation":{"componentType":"select","countVisible":false,"displayName":"Tanggal dipasang","noOptionPlaceholder":"","noOptionValue":"","order":0,"pillVisible":true,"showSelectedFilterAsToggle":true,"truncatedOptionListLength":0,"useAnchorLinkFilterOption":true},"scEnabled":false},{"dataType":"REFINEBY","filterName":"jobtype","noOptionValMap":{"jt":""},"options":[{"@class":"com.indeed.yosegi.model.dynamicfilters.view.ImmutableBucketOption","count":134,"label":"Penuh Waktu","notZrp":true,"paramValMap":{"jt":"","sc":"0kf:jt(fulltime);"},"selected":false,"type":"bucket","url":"\u002Flowongan-kerja?q=frontend+developer&sc=0kf%3Ajt(fulltime)%3B"},{"@class":"com.indeed.yosegi.model.dynamicfilters.view.ImmutableBucketOption","count":26,"label":"Kontrak","notZrp":true,"paramValMap":{"jt":"","sc":"0kf:jt(contract);"},"selected":false,"type":"bucket","url":"\u002Flowongan-kerja?q=frontend+developer&sc=0kf%3Ajt(contract)%3B"},{"@class":"com.indeed.yosegi.model.dynamicfilters.view.ImmutableBucketOption","count":3,"label":"Magang","notZrp":true,"paramValMap":{"jt":"","sc":"0kf:jt(internship);"},"selected":false,"type":"bucket","url":"\u002Flowongan-kerja?q=frontend+developer&sc=0kf%3Ajt(internship)%3B","urlRel":"nofollow"},{"@class":"com.indeed.yosegi.model.dynamicfilters.view.ImmutableBucketOption","count":3,"label":"Paruh Waktu","notZrp":true,"paramValMap":{"jt":"","sc":"0kf:jt(parttime);"},"selected":false,"type":"bucket","url":"\u002Flowongan-kerja?q=frontend+developer&sc=0kf%3Ajt(parttime)%3B","urlRel":"nofollow"},{"@class":"com.indeed.yosegi.model.dynamicfilters.view.ImmutableBucketOption","count":2,"label":"Fresh Grad","notZrp":true,"paramValMap":{"jt":"","sc":"0kf:jt(new_grad);"},"selected":false,"type":"bucket","url":"\u002Flowongan-kerja?q=frontend+developer&sc=0kf%3Ajt(new_grad)%3B","urlRel": ...
#
#     window.mosaic.publicPaths={};
#     window.mosaic.publicPaths["mosaic-provider-reportcontent"]="https://c03.s3.indeed.com/mosaic-provider-reportcontent/dist/";
#     window.mosaic.publicPaths["uip-micro-content-provider"]="https://c03.s3.indeed.com/uip-micro-content-provider/dist/";
#     window.mosaic.publicPaths["mosaic-provider-desktopserp-jobalert-popup"]="https://c03.s3.indeed.com/mosaic-provider-jobalert/dist/";
#     window.mosaic.publicPaths["mosaic-provider-jobsearch-feedback"]="https://c03.s3.indeed.com/mosaic-provider-jobsearch-feedback/dist/";
#     window.mosaic.publicPaths["mosaic-provider-dislike-feedback"]="https://c03.s3.indeed.com/mosaic-provider-jobsearch-feedback/dist/";
#     window.mosaic.publicPaths["mosaic-provider-jobcards"]="https://c03.s3.indeed.com/mosaic-provider-jobcards/dist/";
#     window.mosaic.publicPaths["mosaic-provider-passport-intercept"]="https://c03.s3.indeed.com/mosaic-provider-passport-intercept/dist/";
#     window.mosaic.publicPaths["mosaic-provider-serpreportjob"]="https://c03.s3.indeed.com/mosaic-provider-reportcontent/dist/";
#     window.mosaic.publicPaths["mosaic-provider-desktopserp-jobalert-form"]="https://c03.s3.indeed.com/mosaic-provider-jobalert/dist/";
#     window.mosaic.publicPaths["MosaicProviderRichSearchDaemon"]="https://c03.s3.indeed.com/mosaic-provider-rich-search/static/";
# </script>
# <script async="" crossorigin="anonymous" src="https://c03.s3.indeed.com/mosaic-common/dist/loadProviders.44639c6452e786da37c5.js?cacheKey=1"></script>
# <script id="mosaic-translation-overrides">
#     this.mosaic = this.mosaic || {}; this.mosaic.i18nOverrides = this.mosaic.i18nOverrides || {};
# (function applyTranslations(){this['i18n.mosaic-provider-passport-intercept']={"":{"Content-Type":" text/plain; charset=UTF-8","Locale":"in_ID","Plural-Forms":" nplurals=1; plural=0;"},"Close":[null,"Tutup"],"Loading login form":[null,"Memuat formulir masuk"],"Login Form":[null,"Formulir Masuk"],"Login window":[null,"Jendela masuk"],"Prompts the user to log in to be able to see more jobs in their homepage feed\u0004To see more jobs in your personalized feed, create an account or sign in.":[null,"Buat akun atau masuk untuk melihat lowongan lainnya di umpan personalisasi Anda."]};
# this['i18n.MosaicProviderRichSearchDaemon']={"":{"Content-Type":" text/plain; charset=UTF-8","Locale":"id_ID","Plural-Forms":" nplurals=1; plural=0;","Project-Name":"mosaic-provider-rich-search-java"},"'Apply from your phone' jobs":[null,"Lowongan yang dapat dilamar langsung dari ponsel kamu"],"All Filters":[null,""],"All Job Types":[null,""],"All filters":[null,"Semua filter"],"Back":[null,"Kembali"],"Cancel":[null,"Batalkan"],"Clear":[null,""],"Clear {0} filter":[null,"Hapus filter {0}"],"Current Location":[null,"Lokasi Sekarang"],"Distance":[null,""],"Edit search radius":[null,""],"Exact location":[null,"Lokasi yang tepat"],"Filter {0} has been removed":[null,""],"Filters":[null,"Saring"],"Filters Applied":[null,""],"Job Type":[null,"Jenis Lowongan"],"New":[null,"Baru"],"New jobs":[null,"Lowongan baru"],"No":[null,"Tidak"],"Remove {0} filter":[null,""],"Reset":[null,"Hapus"],"Salary":[null,"Gaji"],"Search":[null,""],"Search jobs at all companies":[null,""],"Search jobs at {0}":[null,""],"Select and press backspace to search jobs at all companies":[null,""],"Select region":[null,""],"Sort by date":[null,""],"Sort by relevance":[null,""],"Update":[null,"Perbarui"],"Yes":[null,"Ya"],"filter":[null,""],"near {0}":[null,""],"search":[null,""],"{0} active filters":[null,""],"{0} filter":[null,"Filter {0}"],"{0} miles":[null,"{0} kilometer"],"{0} search suggestion":["{0} search suggestions","{0} saran pencarian"],"{0}{1} filter":[null,"Filter {1}{0}"],"japan rich search salary\u0004${0}":[null,""],"japan rich search salary\u0004Daily":[null,""],"japan rich search salary\u0004Hourly":[null,""],"japan rich search salary\u0004Maximum Salary":[null,""],"japan rich search salary\u0004Minimum Salary":[null,""],"japan rich search salary\u0004Monthly":[null,""],"japan rich search salary\u0004No limit":[null,""],"japan rich search salary\u0004None":[null,""],"japan rich search salary\u0004Not set":[null,""],"japan rich search salary\u0004The minimum value must be less than the maximum value":[null,""],"japan rich search salary\u0004Yearly":[null,""],"japan rich search salary\u0004above {0} {1}":[null,""],"japan rich search salary\u0004below {0} {1}":[null,""],"japan rich search salary\u0004{0} - {1} {2}":[null,""],"japan search component\u0004(Complete with just your email address)":[null,""],"japan search component\u0004<span class=\"jpsearchcomponent-SaveSearchToast-link\">The selected search criteria</span> has been saved":[null,""],"japan search component\u0004All jobs":[null,""],"japan search component\u0004All jobs in {0}":[null,""],"japan search component\u0004Area":[null,""],"japan search component\u0004By creating a job alert or receiving a recommended job alert, the user is deemed to have agreed to the <a {0}>Terms of Use</a>.":[null,""],"japan search component\u0004Cafe, Nutritionist etc.":[null,""],"japan search component\u0004Cancel":[null,""],"japan search component\u0004Complete selection":[null,""],"japan search component\u0004Confirm":[null,""],"japan search component\u0004Create account":[null,""],"japan search component\u0004Decide":[null,""],"japan search component\u0004Don't show me this message again":[null,""],"japan search component\u0004Exact Location":[null,""],"japan search component\u0004Include external apply":[null,""],"japan search component\u0004Job Age":[null,""],"japan search component\u0004Job Features":[null,""],"japan search component\u0004Let us send you jobs matching your condition!":[null,""],"japan search component\u0004Login":[null,""],"japan search component\u0004Login is required to use this feature":[null,""],"japan search component\u0004New Jobs(Since last search)":[null,""],"japan search component\u0004Occupations":[null,""],"japan search component\u0004Others":[null,""],"japan search component\u0004Radius":[null,""],"japan search component\u0004Recent Search":[null,"Pencarian Terbaru"],"japan search component\u0004Reset":[null,""],"japan search component\u0004Save":[null,""],"japan search com ...
# </script>
# <script async="" type="text/javascript">
#                 function loadScript() {
#                     if (!window.gtag) {
#                         var script = document.createElement('script');
#                         var done = false;
#                         var head = document.getElementsByTagName("head")[0];
#                         script.src = 'https://www.googletagmanager.com/gtag/js?id=DC-' + 8232301;
#                         script.onload = script.onreadystatechange = function() {
#                             if ( !done && (!this.readyState || this.readyState == "loaded" || this.readyState == "complete") ) {
#                                 done = true;
#                                 configureGtag();
#                                 // IE memory leak
#                                 script.onload = script.onreadystatechange = null;
#                                 head.removeChild( script );
#                             }
#                         };
#                         head.appendChild(script);
#                     }
#                 }
#                 function configureGtag() {
#                     window.dataLayer = window.dataLayer || [];
#                     window.gtag = function(){dataLayer.push(arguments);}
#                     gtag('js', new Date());
#                     gtag('config', 'DC-' + 8232301);
#                 }
#                 loadScript();
#             </script>
# <script>
#                 var _comscore = _comscore || [];
#                 _comscore.push({ c1: "2", c2: "6486505", c4:"http://id.indeed.com/jobs?q=frontend%20developer&start=10&l=&from=searchOnHP", c15:""});
#                 (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); })();
#             </script>
# <noscript>
# <img alt="" height="0" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6486505&amp;c4=&amp;c15=&amp;cv=2.0&amp;cj=1" style="display:none" width="0"/>
# </noscript>
# </main>
# </body></html>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 39
#      37     url = 'https://id.indeed.com/jobs?q={}&start={}&l=&from=searchOnHP'.format(job_query,10 + i*10)
#      38     response = requests.get(url, headers=headers)
# ---> 39     result = scrape_job_details(response.content)
#      40     new_results.append(result)
#      41 combined_data = pd.concat(new_results, ignore_index=True)
#
# Cell In[6], line 17, in scrape_job_details(page_source)
#       8 jobs_list = []
#       9 for post in content.select('.job_seen_beacon'):
#      11     data = {
#      12         "job_title": post.find('span', id=lambda x: x and x.startswith('jobTitle')).text,
#      13         "company": post.find('span', class_='css-92r8pb').text,
#      14         "location": post.find('div', class_='css-1p0sjhy').text,
#      15         "posted_date":  post.find('span', attrs={'data-testid': 'myJobsStateDate'}).text,
#      16         "job_description": post.find('div', class_='css-9446fg').text,
# ---> 17         "job_type": post.find('span', class_='css-12bzcbs').text,
#      18         "scrapped_date": pd.to_datetime('today').strftime('%Y-%m-%d')
#      19     }
#      21     try: data["rating"] = post.find('span', attrs={'data-testid': 'holistic-rating'}).text
#      22     except: data["rating"] = 0
#
# AttributeError: 'NoneType' object has no attribute 'text'
